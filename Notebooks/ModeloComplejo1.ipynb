# %% [markdown]
# <font color="FF3B3B"><h1 align="left">Proyecto de aprendizaje profundo</h1></font>
# <font color="#6E6E6E"><h2 align="left">Modelo complejo CNN</h2></font>
#
# ##### David Alejandro Pedroza De Jesús
# ##### Joel Ezequiel Vicente Alonso
#
# Cargamos las librerias para la realización del proyecto

# %%
import sys
sys.path.append("../")
from modelos.CNNComplejo1 import ModeloComplejo
import numpy as np
import pandas as pd
import cv2
import kagglehub
import os
from shutil import move
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # Cargar las imagenes
#
# Hararemos el procesado que hemos hecho antes, tanto con las etiquetas e imagenes.

# %%
path = kagglehub.dataset_download("gpiosenka/cards-image-datasetclassification")
# Out:
# Using Colab cache for faster access to the 'cards-image-datasetclassification' dataset.

# %%
#move(path,os.getcwd())

# %%
datos = pd.read_csv(r"cards-image-datasetclassification/cards.csv")
datos.head()
# Out:
#    class index                   filepaths        labels card type data set
# 0            0  train/ace of clubs/001.jpg  ace of clubs       ace    train
# 1            0  train/ace of clubs/002.jpg  ace of clubs       ace    train
# 2            0  train/ace of clubs/003.jpg  ace of clubs       ace    train
# 3            0  train/ace of clubs/004.jpg  ace of clubs       ace    train
# 4            0  train/ace of clubs/005.jpg  ace of clubs       ace    train

# %% [markdown]
# Arreglamos las rutas.

# %%
rutas_adaptadas = ["cards-image-datasetclassification/" +  ruta for ruta in datos["filepaths"]]
im_buenas = []
im_malas = []
for ru in rutas_adaptadas:
    im = cv2.imread(ru)
    if  im is not None:
        im_buenas.append(ru)
    else:
        im_malas.append(ru)
#print(f"Lecturas correctas: {len(im_buenas)}")
#print(f"Lecturas incorrectas: {len(im_malas)}")

df_limpio = datos[np.array(rutas_adaptadas) != np.array(im_malas)]
df_limpio["rutas_adap"] = im_buenas
# Out:
# /tmp/ipykernel_1339/1813950221.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["rutas_adap"] = im_buenas

# %% [markdown]
# Ahora cargamos las imagenes.

# %%
def CargarImg(path, size):
    img = cv2.imread(path)
    img_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_resize = cv2.resize(img_RGB, size)
    return np.array(img_resize / 255.)

# %%
rutas_train = df_limpio[df_limpio["data set"] == "train"].rutas_adap
rutas_test = df_limpio[df_limpio["data set"] == "test"].rutas_adap
rutas_val = df_limpio[df_limpio["data set"] == "valid"].rutas_adap

X_train = np.array([CargarImg(path, (128, 128)) for path in rutas_train])
X_test = np.array([CargarImg(path, (128, 128)) for path in rutas_test])
X_val = np.array([CargarImg(path, (128, 128)) for path in rutas_val])

y_train = df_limpio[df_limpio["data set"] == "train"]["labels"]
y_test = df_limpio[df_limpio["data set"] == "test"]["labels"]
y_val = df_limpio[df_limpio["data set"] == "valid"]["labels"]

# %% [markdown]
# Y codificamos los labels con `LabelEncoder()`

# %%
encoder = LabelEncoder()

y_train_num = encoder.fit_transform(y_train)
y_val_num   = encoder.transform(y_val)
y_test_num  = encoder.transform(y_test)

# %% [markdown]
# # Arquitectura de la red
#
# En este apartado iremos probando la arquitectura, en este hemos añadido capas dos capas dense y dos capas convolucionales.

# %%
input_shape = X_train[0].shape
num_clases = np.unique(y_train_num).shape[0]
model = ModeloComplejo(input_shape, num_clases)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 124, 124, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 984064)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │    62,980,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 53)             │         3,445 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 63,002,997 (240.34 MB)
#  Trainable params: 63,002,997 (240.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# También aquí hacemos un plot de la arquitectura del modelo.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# # Entrenamiento
#
# En este apartado realizaremos el entrenamiento.

# %%
hist = model.fit(X_train, y_train_num,validation_data=(X_val, y_val_num), epochs=50)
# Out:
# Epoch 1/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - categorical_accuracy: 0.0121 - loss: 8.9180 - val_categorical_accuracy: 0.0491 - val_loss: 1.8624
# Epoch 2/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - categorical_accuracy: 0.0192 - loss: 1.4704 - val_categorical_accuracy: 0.0302 - val_loss: 1.4132
# Epoch 3/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - categorical_accuracy: 0.0155 - loss: 0.4544 - val_categorical_accuracy: 0.0264 - val_loss: 1.5971
# Epoch 4/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - categorical_accuracy: 0.0181 - loss: 0.2001 - val_categorical_accuracy: 0.0226 - val_loss: 1.6951
# Epoch 5/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0203 - loss: 0.1100 - val_categorical_accuracy: 0.0226 - val_loss: 1.7735
# Epoch 6/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - categorical_accuracy: 0.0162 - loss: 0.0675 - val_categorical_accuracy: 0.0226 - val_loss: 2.0049
# Epoch 7/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0207 - loss: 0.0677 - val_categorical_accuracy: 0.0226 - val_loss: 1.8833
# Epoch 8/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - categorical_accuracy: 0.0199 - loss: 0.0266 - val_categorical_accuracy: 0.0264 - val_loss: 1.8764
# Epoch 9/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - categorical_accuracy: 0.0194 - loss: 0.0344 - val_categorical_accuracy: 0.0226 - val_loss: 1.7511
# Epoch 10/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - categorical_accuracy: 0.0185 - loss: 0.0302 - val_categorical_accuracy: 0.0226 - val_loss: 2.0837
# Epoch 11/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0175 - loss: 0.0284 - val_categorical_accuracy: 0.0340 - val_loss: 1.8316
# Epoch 12/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0190 - loss: 0.0218 - val_categorical_accuracy: 0.0264 - val_loss: 2.1215
# Epoch 13/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0187 - loss: 0.0348 - val_categorical_accuracy: 0.0226 - val_loss: 2.0844
# Epoch 14/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0204 - loss: 0.0262 - val_categorical_accuracy: 0.0264 - val_loss: 2.5232
# Epoch 15/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0189 - loss: 0.0433 - val_categorical_accuracy: 0.0264 - val_loss: 2.2219
# Epoch 16/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - categorical_accuracy: 0.0167 - loss: 0.0518 - val_categorical_accuracy: 0.0226 - val_loss: 2.0048
# Epoch 17/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0194 - loss: 0.0200 - val_categorical_accuracy: 0.0264 - val_loss: 2.2646
# Epoch 18/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0194 - loss: 0.0278 - val_categorical_accuracy: 0.0226 - val_loss: 2.3625
# Epoch 19/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0165 - loss: 0.0240 - val_categorical_accuracy: 0.0226 - val_loss: 2.1422
# Epoch 20/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0160 - loss: 0.0123 - val_categorical_accuracy: 0.0189 - val_loss: 2.5697
# Epoch 21/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0229 - loss: 0.0188 - val_categorical_accuracy: 0.0264 - val_loss: 2.4166
# Epoch 22/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0198 - loss: 0.0108 - val_categorical_accuracy: 0.0226 - val_loss: 2.4953
# Epoch 23/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0172 - loss: 0.0093 - val_categorical_accuracy: 0.0189 - val_loss: 2.4424
# Epoch 24/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0176 - loss: 0.0063 - val_categorical_accuracy: 0.0340 - val_loss: 2.8761
# Epoch 25/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0192 - loss: 0.0100 - val_categorical_accuracy: 0.0415 - val_loss: 2.8489
# Epoch 26/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0192 - loss: 0.0218 - val_categorical_accuracy: 0.0340 - val_loss: 2.7955
# Epoch 27/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0227 - loss: 0.0278 - val_categorical_accuracy: 0.0264 - val_loss: 2.8751
# Epoch 28/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0182 - loss: 0.0252 - val_categorical_accuracy: 0.0377 - val_loss: 2.2953
# Epoch 29/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0217 - loss: 0.0100 - val_categorical_accuracy: 0.0264 - val_loss: 2.5392
# Epoch 30/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0153 - loss: 0.0015 - val_categorical_accuracy: 0.0340 - val_loss: 2.4070
# Epoch 31/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0162 - loss: 0.0047 - val_categorical_accuracy: 0.0302 - val_loss: 2.5651
# Epoch 32/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0220 - loss: 5.1318e-04 - val_categorical_accuracy: 0.0302 - val_loss: 2.7590
# Epoch 33/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0201 - loss: 0.0040 - val_categorical_accuracy: 0.0264 - val_loss: 3.1095
# Epoch 34/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0183 - loss: 0.0433 - val_categorical_accuracy: 0.0264 - val_loss: 3.0900
# Epoch 35/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0243 - loss: 0.0552 - val_categorical_accuracy: 0.0226 - val_loss: 3.1641
# Epoch 36/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0229 - loss: 0.0134 - val_categorical_accuracy: 0.0302 - val_loss: 2.7879
# Epoch 37/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0179 - loss: 0.0120 - val_categorical_accuracy: 0.0264 - val_loss: 2.4822
# Epoch 38/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0188 - loss: 0.0072 - val_categorical_accuracy: 0.0302 - val_loss: 2.3799
# Epoch 39/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0231 - loss: 0.0015 - val_categorical_accuracy: 0.0264 - val_loss: 2.4674
# Epoch 40/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0180 - loss: 9.6210e-04 - val_categorical_accuracy: 0.0264 - val_loss: 2.4518
# Epoch 41/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0171 - loss: 5.4670e-04 - val_categorical_accuracy: 0.0264 - val_loss: 2.5571
# Epoch 42/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0212 - loss: 4.2787e-04 - val_categorical_accuracy: 0.0264 - val_loss: 2.4265
# Epoch 43/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0194 - loss: 8.0113e-04 - val_categorical_accuracy: 0.0264 - val_loss: 2.4911
# Epoch 44/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0208 - loss: 6.2545e-04 - val_categorical_accuracy: 0.0264 - val_loss: 2.6095
# Epoch 45/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0217 - loss: 2.4257e-04 - val_categorical_accuracy: 0.0264 - val_loss: 2.6888
# Epoch 46/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0178 - loss: 9.8614e-04 - val_categorical_accuracy: 0.0264 - val_loss: 2.7315
# Epoch 47/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0199 - loss: 5.2259e-04 - val_categorical_accuracy: 0.0264 - val_loss: 2.6787
# Epoch 48/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0189 - loss: 4.6293e-04 - val_categorical_accuracy: 0.0340 - val_loss: 2.8128
# Epoch 49/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0192 - loss: 5.6561e-04 - val_categorical_accuracy: 0.0302 - val_loss: 2.6050
# Epoch 50/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - categorical_accuracy: 0.0199 - loss: 0.0011 - val_categorical_accuracy: 0.0302 - val_loss: 3.2540

# %% [markdown]
# # Evaluación del modelo
#
# En el caso del loss del train vemos que si baja con las epocas y converge, pero con el conjunto validación no ocurre, lo que indica o sobre ajuste o incluso que los datos tienen algo raro.

# %%
loss = hist.history["loss"]
val_loss = hist.history["val_loss"]

plt.plot(loss, label="loss")
plt.plot(val_loss, label="val_loss")
plt.title("Loss")
plt.legend()
plt.show()

# %% [markdown]
# En cuanto el accuracy demuestra que el modelo no esta aprendiendo,

# %%
acc = hist.history["categorical_accuracy"]
val_acc = hist.history["val_categorical_accuracy"]

plt.plot(acc, label="acc")
plt.plot(val_acc, label="val_acc")
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# En este caso vemos lo que ya la curvas nos dicen, el modelo tiene poco error en train, pero es muy alto en test y validación.En cuanto al acuraccy nos esta indicando que el modelo no ha aprendido.

# %%
train_loss, train_acc = model.evaluate(X_train, y_train_num, verbose=0)
val_loss, val_acc = model.evaluate(X_val, y_val_num, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test_num, verbose=0)

print("TRAIN:")
print("Loss:", round(train_loss,3))
print("Accuracy:", round(train_acc,3))

print("\nVALIDATION:")
print("Loss:", round(val_loss,3))
print("Accuracy:", round(val_acc,3))

print("\nTEST:")
print("Loss:", round(test_loss,3))
print("Accuracy:", round(test_acc,3))
# Out:
# TRAIN:
# Loss: 0.012
# Accuracy: 0.013
#
# VALIDATION:
# Loss: 3.254
# Accuracy: 0.03
#
# TEST:
# Loss: 3.286
# Accuracy: 0.015

# %% [markdown]
# # Matriz de confución
#
# En cuanto a las predicciones no parece estar tan mal como parece, debido a que al menos tenemos que en casi todos los casos, en la mayoria acierta.

# %%
class_names = encoder.classes_

cm = confusion_matrix(y_test_num, np.argmax(model.predict(X_test), axis=1), normalize="true")

plt.figure(figsize=(20, 20))
sns.heatmap(cm,
            annot=True, cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names,
            cbar=True)

plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.title('Matriz de Confusión')
plt.yticks(rotation=0)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
