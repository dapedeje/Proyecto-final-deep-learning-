# %% [markdown]
# <font color="FF3B3B"><h1 align="left">Proyecto de aprendizaje profundo</h1></font>
# <font color="#6E6E6E"><h2 align="left">Modelo complejo CNN Nº 7</h2></font>
#
# ##### David Alejandro Pedroza De Jesús
# ##### Joel Ezequiel Vicente Alonso
#
# Cargamos las librerias para la realización del proyecto

# %%
import sys
sys.path.append("../")
from CNNComplejo12 import ModeloComplejo
import numpy as np
import pandas as pd
import cv2
import kagglehub
import os
from shutil import move
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns
from tensorflow.keras.utils import plot_model

# %%
path = kagglehub.dataset_download("gpiosenka/cards-image-datasetclassification")
print(path)
# Out:
# Using Colab cache for faster access to the 'cards-image-datasetclassification' dataset.
# /kaggle/input/cards-image-datasetclassification

# %%
move(path,os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     846     try:
# --> 847         os.rename(src, real_dst)
#     848     except OSError:
#
# OSError: [Errno 18] Invalid cross-device link: '/kaggle/input/cards-image-datasetclassification' -> '/content/cards-image-datasetclassification'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_1916/3271023425.py in <cell line: 0>()
# ----> 1 move(path,os.getcwd())
#
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     863             copytree(src, real_dst, copy_function=copy_function,
#     864                      symlinks=True)
# --> 865             rmtree(src)
#     866         else:
#     867             copy_function(src, real_dst)
#
# /usr/lib/python3.12/shutil.py in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     757         try:
#     758             while stack:
# --> 759                 _rmtree_safe_fd(stack, onexc)
#     760         finally:
#     761             # Close any file descriptors still on the stack.
#
# /usr/lib/python3.12/shutil.py in _rmtree_safe_fd(stack, onexc)
#     701     except OSError as err:
#     702         err.filename = path
# --> 703         onexc(func, path, err)
#     704
#     705 _use_fd_functions = ({os.open, os.stat, os.unlink, os.rmdir} <=
#
# /usr/lib/python3.12/shutil.py in _rmtree_safe_fd(stack, onexc)
#     698                 os.unlink(entry.name, dir_fd=topfd)
#     699             except OSError as err:
# --> 700                 onexc(os.unlink, fullname, err)
#     701     except OSError as err:
#     702         err.filename = path
#
# /usr/lib/python3.12/shutil.py in _rmtree_safe_fd(stack, onexc)
#     696                 pass
#     697             try:
# --> 698                 os.unlink(entry.name, dir_fd=topfd)
#     699             except OSError as err:
#     700                 onexc(os.unlink, fullname, err)
#
# OSError: [Errno 30] Read-only file system: '/kaggle/input/cards-image-datasetclassification'

# %%
os.rename("2","cards-image-datasetclassification")

# %% [markdown]
# # Resumen
#
# En este caso hemos decidico probar aplicando un upsampling, el cual es una capa que es contraria a la convolución, para ver si da buenos resultados.

# %% [markdown]
# # Cargar las imagenes
#
# Hararemos el procesado que hemos hecho antes, tanto con las etiquetas e imagenes.

# %%
datos = pd.read_csv(r"cards-image-datasetclassification/cards.csv")
datos.head()
# Out:
#    class index                   filepaths        labels card type data set
# 0            0  train/ace of clubs/001.jpg  ace of clubs       ace    train
# 1            0  train/ace of clubs/002.jpg  ace of clubs       ace    train
# 2            0  train/ace of clubs/003.jpg  ace of clubs       ace    train
# 3            0  train/ace of clubs/004.jpg  ace of clubs       ace    train
# 4            0  train/ace of clubs/005.jpg  ace of clubs       ace    train

# %% [markdown]
# Arreglamos las rutas.

# %%
rutas_adaptadas = ["cards-image-datasetclassification/" +  ruta for ruta in datos["filepaths"]]
im_buenas = []
im_malas = []
for ru in rutas_adaptadas:
    im = cv2.imread(ru)
    if  im is not None:
        im_buenas.append(ru)
    else:
        im_malas.append(ru)
#print(f"Lecturas correctas: {len(im_buenas)}")
#print(f"Lecturas incorrectas: {len(im_malas)}")

df_limpio = datos[np.array(rutas_adaptadas) != np.array(im_malas)]
df_limpio["rutas_adap"] = im_buenas
# Out:
# /tmp/ipykernel_1916/1813950221.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["rutas_adap"] = im_buenas

# %% [markdown]
# Ahora cargamos las imagenes, añadiremos un procesado más, debido a que no necesitamos toda la carta para realizar la predicción.

# %%
def CargarImg(path, size):
    img = cv2.imread(path)
    img_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)[0:75,0:75]#De con esto ya tenemos toda la información
    img_resize = cv2.resize(img_RGB, size)
    return np.array(img_resize / 255.)

# %%
rutas_train = df_limpio[df_limpio["data set"] == "train"].rutas_adap
rutas_test = df_limpio[df_limpio["data set"] == "test"].rutas_adap
rutas_val = df_limpio[df_limpio["data set"] == "valid"].rutas_adap

X_train = np.array([CargarImg(path, (75, 75)) for path in rutas_train])
X_test = np.array([CargarImg(path, (75, 75)) for path in rutas_test])
X_val = np.array([CargarImg(path, (75, 75)) for path in rutas_val])

y_train = df_limpio[df_limpio["data set"] == "train"]["labels"]
y_test = df_limpio[df_limpio["data set"] == "test"]["labels"]
y_val = df_limpio[df_limpio["data set"] == "valid"]["labels"]

# %% [markdown]
# Y codificamos los labels con `LabelEncoder()`

# %%
encoder = LabelEncoder()

y_train_num = encoder.fit_transform(y_train)
y_val_num   = encoder.transform(y_val)
y_test_num  = encoder.transform(y_test)

# %% [markdown]
# # Arquitectura de la red
#
# En este apartado iremos probando la arquitectura, en este hemos añadido capas dos capas dense y dos capas convolucionales.

# %%
input_shape = X_train[0].shape
num_clases = np.unique(y_train_num).shape[0]
model = ModeloComplejo(input_shape, num_clases)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 75, 75, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 75, 75, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 75, 75, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 75, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 37, 37, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 74, 74, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 74, 74, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 74, 74, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 74, 74, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 37, 37, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 18, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 18, 18, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 18, 18, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 18, 18, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 9, 9, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 9, 9, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 5184)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       331,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        16,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 53)             │        13,621 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 395,765 (1.51 MB)
#  Trainable params: 395,349 (1.51 MB)
#  Non-trainable params: 416 (1.62 KB)

# %% [markdown]
# También aquí hacemos un plot de la arquitectura del modelo.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# # Entrenamiento
#
# En este apartado realizaremos el entrenamiento.

# %%
hist = model.fit(X_train, y_train_num,validation_data=(X_val, y_val_num), epochs=350)
# Out:
# Epoch 1/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 28s 56ms/step - loss: 3.6061 - sparse_categorical_accuracy: 0.0675 - val_loss: 4.1660 - val_sparse_categorical_accuracy: 0.0340
# Epoch 2/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 3.0639 - sparse_categorical_accuracy: 0.1455 - val_loss: 2.7290 - val_sparse_categorical_accuracy: 0.2264
# Epoch 3/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.7012 - sparse_categorical_accuracy: 0.2286 - val_loss: 2.2446 - val_sparse_categorical_accuracy: 0.2906
# Epoch 4/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.3915 - sparse_categorical_accuracy: 0.3118 - val_loss: 1.6201 - val_sparse_categorical_accuracy: 0.5132
# Epoch 5/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.1460 - sparse_categorical_accuracy: 0.3760 - val_loss: 1.2860 - val_sparse_categorical_accuracy: 0.6453
# Epoch 6/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.9228 - sparse_categorical_accuracy: 0.4431 - val_loss: 1.1519 - val_sparse_categorical_accuracy: 0.6415
# Epoch 7/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7905 - sparse_categorical_accuracy: 0.4765 - val_loss: 1.1090 - val_sparse_categorical_accuracy: 0.6906
# Epoch 8/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6552 - sparse_categorical_accuracy: 0.5109 - val_loss: 0.7872 - val_sparse_categorical_accuracy: 0.8038
# Epoch 9/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5393 - sparse_categorical_accuracy: 0.5508 - val_loss: 0.7844 - val_sparse_categorical_accuracy: 0.8000
# Epoch 10/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.4669 - sparse_categorical_accuracy: 0.5620 - val_loss: 0.7516 - val_sparse_categorical_accuracy: 0.8151
# Epoch 11/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.3703 - sparse_categorical_accuracy: 0.5981 - val_loss: 0.7370 - val_sparse_categorical_accuracy: 0.8226
# Epoch 12/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.3264 - sparse_categorical_accuracy: 0.6171 - val_loss: 0.7194 - val_sparse_categorical_accuracy: 0.8038
# Epoch 13/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2325 - sparse_categorical_accuracy: 0.6379 - val_loss: 0.5498 - val_sparse_categorical_accuracy: 0.8755
# Epoch 14/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.1955 - sparse_categorical_accuracy: 0.6438 - val_loss: 0.5331 - val_sparse_categorical_accuracy: 0.8604
# Epoch 15/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.1694 - sparse_categorical_accuracy: 0.6548 - val_loss: 0.5275 - val_sparse_categorical_accuracy: 0.8717
# Epoch 16/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.1167 - sparse_categorical_accuracy: 0.6671 - val_loss: 0.5576 - val_sparse_categorical_accuracy: 0.8528
# Epoch 17/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.0506 - sparse_categorical_accuracy: 0.6901 - val_loss: 0.5759 - val_sparse_categorical_accuracy: 0.8491
# Epoch 18/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0371 - sparse_categorical_accuracy: 0.6897 - val_loss: 0.4977 - val_sparse_categorical_accuracy: 0.8604
# Epoch 19/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.9649 - sparse_categorical_accuracy: 0.7093 - val_loss: 0.3956 - val_sparse_categorical_accuracy: 0.8868
# Epoch 20/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.9297 - sparse_categorical_accuracy: 0.7192 - val_loss: 0.5099 - val_sparse_categorical_accuracy: 0.8868
# Epoch 21/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.9370 - sparse_categorical_accuracy: 0.7211 - val_loss: 0.4014 - val_sparse_categorical_accuracy: 0.8830
# Epoch 22/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8956 - sparse_categorical_accuracy: 0.7307 - val_loss: 0.4478 - val_sparse_categorical_accuracy: 0.8943
# Epoch 23/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8559 - sparse_categorical_accuracy: 0.7471 - val_loss: 0.3247 - val_sparse_categorical_accuracy: 0.9170
# Epoch 24/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8425 - sparse_categorical_accuracy: 0.7404 - val_loss: 0.4280 - val_sparse_categorical_accuracy: 0.8792
# Epoch 25/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8670 - sparse_categorical_accuracy: 0.7379 - val_loss: 0.4411 - val_sparse_categorical_accuracy: 0.8981
# Epoch 26/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8042 - sparse_categorical_accuracy: 0.7567 - val_loss: 0.3558 - val_sparse_categorical_accuracy: 0.8943
# Epoch 27/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.8005 - sparse_categorical_accuracy: 0.7587 - val_loss: 0.2826 - val_sparse_categorical_accuracy: 0.9321
# Epoch 28/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7708 - sparse_categorical_accuracy: 0.7692 - val_loss: 0.3044 - val_sparse_categorical_accuracy: 0.9170
# Epoch 29/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7601 - sparse_categorical_accuracy: 0.7699 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.9208
# Epoch 30/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7508 - sparse_categorical_accuracy: 0.7720 - val_loss: 0.3722 - val_sparse_categorical_accuracy: 0.8906
# Epoch 31/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7516 - sparse_categorical_accuracy: 0.7728 - val_loss: 0.2610 - val_sparse_categorical_accuracy: 0.9396
# Epoch 32/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7222 - sparse_categorical_accuracy: 0.7824 - val_loss: 0.4393 - val_sparse_categorical_accuracy: 0.8830
# Epoch 33/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6818 - sparse_categorical_accuracy: 0.7891 - val_loss: 0.3148 - val_sparse_categorical_accuracy: 0.9208
# Epoch 34/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7007 - sparse_categorical_accuracy: 0.7883 - val_loss: 0.2797 - val_sparse_categorical_accuracy: 0.9245
# Epoch 35/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6783 - sparse_categorical_accuracy: 0.7876 - val_loss: 0.3558 - val_sparse_categorical_accuracy: 0.9094
# Epoch 36/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6542 - sparse_categorical_accuracy: 0.7998 - val_loss: 0.3342 - val_sparse_categorical_accuracy: 0.9170
# Epoch 37/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6716 - sparse_categorical_accuracy: 0.7953 - val_loss: 0.2753 - val_sparse_categorical_accuracy: 0.9283
# Epoch 38/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6510 - sparse_categorical_accuracy: 0.8034 - val_loss: 0.3247 - val_sparse_categorical_accuracy: 0.9019
# Epoch 39/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6366 - sparse_categorical_accuracy: 0.8069 - val_loss: 0.3037 - val_sparse_categorical_accuracy: 0.9132
# Epoch 40/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6538 - sparse_categorical_accuracy: 0.8034 - val_loss: 0.2735 - val_sparse_categorical_accuracy: 0.9208
# Epoch 41/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6097 - sparse_categorical_accuracy: 0.8141 - val_loss: 0.2473 - val_sparse_categorical_accuracy: 0.9358
# Epoch 42/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6005 - sparse_categorical_accuracy: 0.8152 - val_loss: 0.3943 - val_sparse_categorical_accuracy: 0.8868
# Epoch 43/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5963 - sparse_categorical_accuracy: 0.8131 - val_loss: 0.3781 - val_sparse_categorical_accuracy: 0.8830
# Epoch 44/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6164 - sparse_categorical_accuracy: 0.8144 - val_loss: 0.2808 - val_sparse_categorical_accuracy: 0.9321
# Epoch 45/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6101 - sparse_categorical_accuracy: 0.8116 - val_loss: 0.2845 - val_sparse_categorical_accuracy: 0.9170
# Epoch 46/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6000 - sparse_categorical_accuracy: 0.8153 - val_loss: 0.3168 - val_sparse_categorical_accuracy: 0.9094
# Epoch 47/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5880 - sparse_categorical_accuracy: 0.8130 - val_loss: 0.2194 - val_sparse_categorical_accuracy: 0.9396
# Epoch 48/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5580 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.2335 - val_sparse_categorical_accuracy: 0.9321
# Epoch 49/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5455 - sparse_categorical_accuracy: 0.8326 - val_loss: 0.3225 - val_sparse_categorical_accuracy: 0.9170
# Epoch 50/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5531 - sparse_categorical_accuracy: 0.8341 - val_loss: 0.2716 - val_sparse_categorical_accuracy: 0.9321
# Epoch 51/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5536 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.2354 - val_sparse_categorical_accuracy: 0.9472
# Epoch 52/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5443 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.3298 - val_sparse_categorical_accuracy: 0.9019
# Epoch 53/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5664 - sparse_categorical_accuracy: 0.8263 - val_loss: 0.2820 - val_sparse_categorical_accuracy: 0.9170
# Epoch 54/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5276 - sparse_categorical_accuracy: 0.8358 - val_loss: 0.2560 - val_sparse_categorical_accuracy: 0.9208
# Epoch 55/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5491 - sparse_categorical_accuracy: 0.8292 - val_loss: 0.3218 - val_sparse_categorical_accuracy: 0.8981
# Epoch 56/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5356 - sparse_categorical_accuracy: 0.8322 - val_loss: 0.3096 - val_sparse_categorical_accuracy: 0.9132
# Epoch 57/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5187 - sparse_categorical_accuracy: 0.8417 - val_loss: 0.2810 - val_sparse_categorical_accuracy: 0.9208
# Epoch 58/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5324 - sparse_categorical_accuracy: 0.8423 - val_loss: 0.2504 - val_sparse_categorical_accuracy: 0.9509
# Epoch 59/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5034 - sparse_categorical_accuracy: 0.8451 - val_loss: 0.2709 - val_sparse_categorical_accuracy: 0.9321
# Epoch 60/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5125 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.2114 - val_sparse_categorical_accuracy: 0.9472
# Epoch 61/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5100 - sparse_categorical_accuracy: 0.8439 - val_loss: 0.2490 - val_sparse_categorical_accuracy: 0.9321
# Epoch 62/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4902 - sparse_categorical_accuracy: 0.8447 - val_loss: 0.2576 - val_sparse_categorical_accuracy: 0.9283
# Epoch 63/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5152 - sparse_categorical_accuracy: 0.8463 - val_loss: 0.3047 - val_sparse_categorical_accuracy: 0.9208
# Epoch 64/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.4957 - sparse_categorical_accuracy: 0.8481 - val_loss: 0.2134 - val_sparse_categorical_accuracy: 0.9472
# Epoch 65/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4781 - sparse_categorical_accuracy: 0.8515 - val_loss: 0.2551 - val_sparse_categorical_accuracy: 0.9472
# Epoch 66/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4857 - sparse_categorical_accuracy: 0.8527 - val_loss: 0.3005 - val_sparse_categorical_accuracy: 0.9245
# Epoch 67/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4980 - sparse_categorical_accuracy: 0.8464 - val_loss: 0.2387 - val_sparse_categorical_accuracy: 0.9358
# Epoch 68/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4859 - sparse_categorical_accuracy: 0.8472 - val_loss: 0.2407 - val_sparse_categorical_accuracy: 0.9434
# Epoch 69/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4789 - sparse_categorical_accuracy: 0.8538 - val_loss: 0.2263 - val_sparse_categorical_accuracy: 0.9472
# Epoch 70/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4761 - sparse_categorical_accuracy: 0.8489 - val_loss: 0.2739 - val_sparse_categorical_accuracy: 0.9396
# Epoch 71/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4791 - sparse_categorical_accuracy: 0.8527 - val_loss: 0.3633 - val_sparse_categorical_accuracy: 0.9019
# Epoch 72/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4826 - sparse_categorical_accuracy: 0.8560 - val_loss: 0.2480 - val_sparse_categorical_accuracy: 0.9396
# Epoch 73/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4816 - sparse_categorical_accuracy: 0.8539 - val_loss: 0.2659 - val_sparse_categorical_accuracy: 0.9358
# Epoch 74/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4494 - sparse_categorical_accuracy: 0.8619 - val_loss: 0.2440 - val_sparse_categorical_accuracy: 0.9396
# Epoch 75/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.4716 - sparse_categorical_accuracy: 0.8562 - val_loss: 0.2585 - val_sparse_categorical_accuracy: 0.9283
# Epoch 76/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4705 - sparse_categorical_accuracy: 0.8561 - val_loss: 0.3147 - val_sparse_categorical_accuracy: 0.9132
# Epoch 77/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4593 - sparse_categorical_accuracy: 0.8595 - val_loss: 0.2143 - val_sparse_categorical_accuracy: 0.9396
# Epoch 78/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4487 - sparse_categorical_accuracy: 0.8624 - val_loss: 0.2519 - val_sparse_categorical_accuracy: 0.9170
# Epoch 79/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4281 - sparse_categorical_accuracy: 0.8659 - val_loss: 0.2189 - val_sparse_categorical_accuracy: 0.9472
# Epoch 80/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4607 - sparse_categorical_accuracy: 0.8606 - val_loss: 0.2233 - val_sparse_categorical_accuracy: 0.9472
# Epoch 81/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.4427 - sparse_categorical_accuracy: 0.8679 - val_loss: 0.2478 - val_sparse_categorical_accuracy: 0.9358
# Epoch 82/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4442 - sparse_categorical_accuracy: 0.8635 - val_loss: 0.3190 - val_sparse_categorical_accuracy: 0.9094
# Epoch 83/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4318 - sparse_categorical_accuracy: 0.8639 - val_loss: 0.2393 - val_sparse_categorical_accuracy: 0.9396
# Epoch 84/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4321 - sparse_categorical_accuracy: 0.8669 - val_loss: 0.2295 - val_sparse_categorical_accuracy: 0.9321
# Epoch 85/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4206 - sparse_categorical_accuracy: 0.8700 - val_loss: 0.2507 - val_sparse_categorical_accuracy: 0.9245
# Epoch 86/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4338 - sparse_categorical_accuracy: 0.8650 - val_loss: 0.6201 - val_sparse_categorical_accuracy: 0.8189
# Epoch 87/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4365 - sparse_categorical_accuracy: 0.8646 - val_loss: 0.2287 - val_sparse_categorical_accuracy: 0.9472
# Epoch 88/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4145 - sparse_categorical_accuracy: 0.8719 - val_loss: 0.2203 - val_sparse_categorical_accuracy: 0.9547
# Epoch 89/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4190 - sparse_categorical_accuracy: 0.8717 - val_loss: 0.2681 - val_sparse_categorical_accuracy: 0.9321
# Epoch 90/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4053 - sparse_categorical_accuracy: 0.8700 - val_loss: 0.3166 - val_sparse_categorical_accuracy: 0.9208
# Epoch 91/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4097 - sparse_categorical_accuracy: 0.8683 - val_loss: 0.2969 - val_sparse_categorical_accuracy: 0.9208
# Epoch 92/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4066 - sparse_categorical_accuracy: 0.8699 - val_loss: 0.2705 - val_sparse_categorical_accuracy: 0.9245
# Epoch 93/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4106 - sparse_categorical_accuracy: 0.8694 - val_loss: 0.2389 - val_sparse_categorical_accuracy: 0.9283
# Epoch 94/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4164 - sparse_categorical_accuracy: 0.8740 - val_loss: 0.1979 - val_sparse_categorical_accuracy: 0.9509
# Epoch 95/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3976 - sparse_categorical_accuracy: 0.8749 - val_loss: 0.2015 - val_sparse_categorical_accuracy: 0.9358
# Epoch 96/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4206 - sparse_categorical_accuracy: 0.8701 - val_loss: 0.2037 - val_sparse_categorical_accuracy: 0.9396
# Epoch 97/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3999 - sparse_categorical_accuracy: 0.8789 - val_loss: 0.1939 - val_sparse_categorical_accuracy: 0.9396
# Epoch 98/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4020 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.2306 - val_sparse_categorical_accuracy: 0.9245
# Epoch 99/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4268 - sparse_categorical_accuracy: 0.8717 - val_loss: 0.2941 - val_sparse_categorical_accuracy: 0.9245
# Epoch 100/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4262 - sparse_categorical_accuracy: 0.8649 - val_loss: 0.2213 - val_sparse_categorical_accuracy: 0.9434
# Epoch 101/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4063 - sparse_categorical_accuracy: 0.8722 - val_loss: 0.2457 - val_sparse_categorical_accuracy: 0.9358
# Epoch 102/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4051 - sparse_categorical_accuracy: 0.8720 - val_loss: 0.2117 - val_sparse_categorical_accuracy: 0.9509
# Epoch 103/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3946 - sparse_categorical_accuracy: 0.8796 - val_loss: 0.2040 - val_sparse_categorical_accuracy: 0.9434
# Epoch 104/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4074 - sparse_categorical_accuracy: 0.8721 - val_loss: 0.2351 - val_sparse_categorical_accuracy: 0.9434
# Epoch 105/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.4006 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.1737 - val_sparse_categorical_accuracy: 0.9472
# Epoch 106/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3926 - sparse_categorical_accuracy: 0.8802 - val_loss: 0.2656 - val_sparse_categorical_accuracy: 0.9283
# Epoch 107/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3856 - sparse_categorical_accuracy: 0.8812 - val_loss: 0.2144 - val_sparse_categorical_accuracy: 0.9434
# Epoch 108/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3913 - sparse_categorical_accuracy: 0.8772 - val_loss: 0.2484 - val_sparse_categorical_accuracy: 0.9321
# Epoch 109/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3771 - sparse_categorical_accuracy: 0.8855 - val_loss: 0.2220 - val_sparse_categorical_accuracy: 0.9434
# Epoch 110/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.3755 - sparse_categorical_accuracy: 0.8847 - val_loss: 0.1901 - val_sparse_categorical_accuracy: 0.9472
# Epoch 111/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3809 - sparse_categorical_accuracy: 0.8789 - val_loss: 0.2371 - val_sparse_categorical_accuracy: 0.9396
# Epoch 112/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3730 - sparse_categorical_accuracy: 0.8821 - val_loss: 0.2716 - val_sparse_categorical_accuracy: 0.9283
# Epoch 113/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3697 - sparse_categorical_accuracy: 0.8868 - val_loss: 0.2301 - val_sparse_categorical_accuracy: 0.9472
# Epoch 114/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.3773 - sparse_categorical_accuracy: 0.8827 - val_loss: 0.2509 - val_sparse_categorical_accuracy: 0.9396
# Epoch 115/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3803 - sparse_categorical_accuracy: 0.8817 - val_loss: 0.2408 - val_sparse_categorical_accuracy: 0.9321
# Epoch 116/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3700 - sparse_categorical_accuracy: 0.8851 - val_loss: 0.2390 - val_sparse_categorical_accuracy: 0.9358
# Epoch 117/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3851 - sparse_categorical_accuracy: 0.8776 - val_loss: 0.2356 - val_sparse_categorical_accuracy: 0.9509
# Epoch 118/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3771 - sparse_categorical_accuracy: 0.8805 - val_loss: 0.2683 - val_sparse_categorical_accuracy: 0.9321
# Epoch 119/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.3703 - sparse_categorical_accuracy: 0.8886 - val_loss: 0.2786 - val_sparse_categorical_accuracy: 0.9358
# Epoch 120/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3699 - sparse_categorical_accuracy: 0.8837 - val_loss: 0.2772 - val_sparse_categorical_accuracy: 0.9434
# Epoch 121/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.3784 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.2335 - val_sparse_categorical_accuracy: 0.9396
# Epoch 122/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3644 - sparse_categorical_accuracy: 0.8818 - val_loss: 0.2294 - val_sparse_categorical_accuracy: 0.9321
# Epoch 123/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3816 - sparse_categorical_accuracy: 0.8822 - val_loss: 0.2328 - val_sparse_categorical_accuracy: 0.9396
# Epoch 124/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3584 - sparse_categorical_accuracy: 0.8882 - val_loss: 0.2625 - val_sparse_categorical_accuracy: 0.9321
# Epoch 125/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3802 - sparse_categorical_accuracy: 0.8852 - val_loss: 0.2239 - val_sparse_categorical_accuracy: 0.9434
# Epoch 126/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3538 - sparse_categorical_accuracy: 0.8903 - val_loss: 0.2298 - val_sparse_categorical_accuracy: 0.9283
# Epoch 127/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3721 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.2820 - val_sparse_categorical_accuracy: 0.9208
# Epoch 128/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3619 - sparse_categorical_accuracy: 0.8852 - val_loss: 0.2288 - val_sparse_categorical_accuracy: 0.9283
# Epoch 129/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3692 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.2392 - val_sparse_categorical_accuracy: 0.9434
# Epoch 130/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3553 - sparse_categorical_accuracy: 0.8900 - val_loss: 0.2227 - val_sparse_categorical_accuracy: 0.9472
# Epoch 131/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3443 - sparse_categorical_accuracy: 0.8928 - val_loss: 0.2533 - val_sparse_categorical_accuracy: 0.9396
# Epoch 132/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3460 - sparse_categorical_accuracy: 0.8877 - val_loss: 0.2567 - val_sparse_categorical_accuracy: 0.9321
# Epoch 133/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3554 - sparse_categorical_accuracy: 0.8884 - val_loss: 0.2142 - val_sparse_categorical_accuracy: 0.9547
# Epoch 134/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.3585 - sparse_categorical_accuracy: 0.8902 - val_loss: 0.2535 - val_sparse_categorical_accuracy: 0.9321
# Epoch 135/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3670 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.2373 - val_sparse_categorical_accuracy: 0.9283
# Epoch 136/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3528 - sparse_categorical_accuracy: 0.8907 - val_loss: 0.2233 - val_sparse_categorical_accuracy: 0.9396
# Epoch 137/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3392 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.2778 - val_sparse_categorical_accuracy: 0.9321
# Epoch 138/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.3589 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.3069 - val_sparse_categorical_accuracy: 0.9094
# Epoch 139/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3465 - sparse_categorical_accuracy: 0.8932 - val_loss: 0.2150 - val_sparse_categorical_accuracy: 0.9509
# Epoch 140/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3362 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.2115 - val_sparse_categorical_accuracy: 0.9472
# Epoch 141/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3482 - sparse_categorical_accuracy: 0.8913 - val_loss: 0.2278 - val_sparse_categorical_accuracy: 0.9283
# Epoch 142/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3707 - sparse_categorical_accuracy: 0.8876 - val_loss: 0.2619 - val_sparse_categorical_accuracy: 0.9396
# Epoch 143/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3329 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.2724 - val_sparse_categorical_accuracy: 0.9358
# Epoch 144/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3477 - sparse_categorical_accuracy: 0.8928 - val_loss: 0.2362 - val_sparse_categorical_accuracy: 0.9208
# Epoch 145/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3501 - sparse_categorical_accuracy: 0.8888 - val_loss: 0.3072 - val_sparse_categorical_accuracy: 0.9358
# Epoch 146/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3282 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.2239 - val_sparse_categorical_accuracy: 0.9434
# Epoch 147/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3289 - sparse_categorical_accuracy: 0.8977 - val_loss: 0.2050 - val_sparse_categorical_accuracy: 0.9434
# Epoch 148/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3295 - sparse_categorical_accuracy: 0.8987 - val_loss: 0.2288 - val_sparse_categorical_accuracy: 0.9321
# Epoch 149/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3393 - sparse_categorical_accuracy: 0.8930 - val_loss: 0.2219 - val_sparse_categorical_accuracy: 0.9434
# Epoch 150/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3334 - sparse_categorical_accuracy: 0.8973 - val_loss: 0.2561 - val_sparse_categorical_accuracy: 0.9283
# Epoch 151/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3447 - sparse_categorical_accuracy: 0.8926 - val_loss: 0.2109 - val_sparse_categorical_accuracy: 0.9434
# Epoch 152/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3262 - sparse_categorical_accuracy: 0.8995 - val_loss: 0.2239 - val_sparse_categorical_accuracy: 0.9321
# Epoch 153/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3341 - sparse_categorical_accuracy: 0.8949 - val_loss: 0.1976 - val_sparse_categorical_accuracy: 0.9434
# Epoch 154/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3457 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.2012 - val_sparse_categorical_accuracy: 0.9396
# Epoch 155/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3234 - sparse_categorical_accuracy: 0.8998 - val_loss: 0.1917 - val_sparse_categorical_accuracy: 0.9472
# Epoch 156/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3296 - sparse_categorical_accuracy: 0.9008 - val_loss: 0.1835 - val_sparse_categorical_accuracy: 0.9547
# Epoch 157/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3340 - sparse_categorical_accuracy: 0.8978 - val_loss: 0.2155 - val_sparse_categorical_accuracy: 0.9396
# Epoch 158/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3335 - sparse_categorical_accuracy: 0.8960 - val_loss: 0.2510 - val_sparse_categorical_accuracy: 0.9396
# Epoch 159/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3179 - sparse_categorical_accuracy: 0.9016 - val_loss: 0.2454 - val_sparse_categorical_accuracy: 0.9358
# Epoch 160/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3254 - sparse_categorical_accuracy: 0.8991 - val_loss: 0.2238 - val_sparse_categorical_accuracy: 0.9396
# Epoch 161/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3289 - sparse_categorical_accuracy: 0.8969 - val_loss: 0.2121 - val_sparse_categorical_accuracy: 0.9472
# Epoch 162/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3385 - sparse_categorical_accuracy: 0.8938 - val_loss: 0.1901 - val_sparse_categorical_accuracy: 0.9509
# Epoch 163/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3314 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.2845 - val_sparse_categorical_accuracy: 0.9358
# Epoch 164/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3284 - sparse_categorical_accuracy: 0.8972 - val_loss: 0.1792 - val_sparse_categorical_accuracy: 0.9509
# Epoch 165/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3393 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.2225 - val_sparse_categorical_accuracy: 0.9358
# Epoch 166/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3265 - sparse_categorical_accuracy: 0.8981 - val_loss: 0.2405 - val_sparse_categorical_accuracy: 0.9358
# Epoch 167/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3194 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.2348 - val_sparse_categorical_accuracy: 0.9396
# Epoch 168/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3139 - sparse_categorical_accuracy: 0.9018 - val_loss: 0.2553 - val_sparse_categorical_accuracy: 0.9358
# Epoch 169/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3007 - sparse_categorical_accuracy: 0.9056 - val_loss: 0.2491 - val_sparse_categorical_accuracy: 0.9396
# Epoch 170/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3129 - sparse_categorical_accuracy: 0.8993 - val_loss: 0.2414 - val_sparse_categorical_accuracy: 0.9283
# Epoch 171/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3164 - sparse_categorical_accuracy: 0.9019 - val_loss: 0.2176 - val_sparse_categorical_accuracy: 0.9396
# Epoch 172/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.3138 - sparse_categorical_accuracy: 0.9006 - val_loss: 0.2439 - val_sparse_categorical_accuracy: 0.9472
# Epoch 173/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3052 - sparse_categorical_accuracy: 0.9052 - val_loss: 0.2297 - val_sparse_categorical_accuracy: 0.9396
# Epoch 174/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3171 - sparse_categorical_accuracy: 0.9007 - val_loss: 0.2120 - val_sparse_categorical_accuracy: 0.9396
# Epoch 175/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3151 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.2139 - val_sparse_categorical_accuracy: 0.9396
# Epoch 176/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3175 - sparse_categorical_accuracy: 0.8990 - val_loss: 0.2223 - val_sparse_categorical_accuracy: 0.9434
# Epoch 177/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3134 - sparse_categorical_accuracy: 0.9037 - val_loss: 0.2015 - val_sparse_categorical_accuracy: 0.9472
# Epoch 178/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3067 - sparse_categorical_accuracy: 0.9028 - val_loss: 0.2131 - val_sparse_categorical_accuracy: 0.9396
# Epoch 179/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.3162 - sparse_categorical_accuracy: 0.9022 - val_loss: 0.2098 - val_sparse_categorical_accuracy: 0.9434
# Epoch 180/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3057 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.2305 - val_sparse_categorical_accuracy: 0.9358
# Epoch 181/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3070 - sparse_categorical_accuracy: 0.9041 - val_loss: 0.2858 - val_sparse_categorical_accuracy: 0.9358
# Epoch 182/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3054 - sparse_categorical_accuracy: 0.9037 - val_loss: 0.2397 - val_sparse_categorical_accuracy: 0.9283
# Epoch 183/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3060 - sparse_categorical_accuracy: 0.9033 - val_loss: 0.2362 - val_sparse_categorical_accuracy: 0.9434
# Epoch 184/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2999 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2580 - val_sparse_categorical_accuracy: 0.9434
# Epoch 185/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3122 - sparse_categorical_accuracy: 0.9052 - val_loss: 0.2302 - val_sparse_categorical_accuracy: 0.9396
# Epoch 186/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.3169 - sparse_categorical_accuracy: 0.9022 - val_loss: 0.2489 - val_sparse_categorical_accuracy: 0.9509
# Epoch 187/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3258 - sparse_categorical_accuracy: 0.9001 - val_loss: 0.2260 - val_sparse_categorical_accuracy: 0.9358
# Epoch 188/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3006 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.2369 - val_sparse_categorical_accuracy: 0.9358
# Epoch 189/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3014 - sparse_categorical_accuracy: 0.9071 - val_loss: 0.2685 - val_sparse_categorical_accuracy: 0.9283
# Epoch 190/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2988 - sparse_categorical_accuracy: 0.9058 - val_loss: 0.2388 - val_sparse_categorical_accuracy: 0.9396
# Epoch 191/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2801 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.2869 - val_sparse_categorical_accuracy: 0.9245
# Epoch 192/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2992 - sparse_categorical_accuracy: 0.9099 - val_loss: 0.2688 - val_sparse_categorical_accuracy: 0.9358
# Epoch 193/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2975 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.2763 - val_sparse_categorical_accuracy: 0.9358
# Epoch 194/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2916 - sparse_categorical_accuracy: 0.9071 - val_loss: 0.2693 - val_sparse_categorical_accuracy: 0.9283
# Epoch 195/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2960 - sparse_categorical_accuracy: 0.9073 - val_loss: 0.2173 - val_sparse_categorical_accuracy: 0.9434
# Epoch 196/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3072 - sparse_categorical_accuracy: 0.9041 - val_loss: 0.2335 - val_sparse_categorical_accuracy: 0.9396
# Epoch 197/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3056 - sparse_categorical_accuracy: 0.9070 - val_loss: 0.2458 - val_sparse_categorical_accuracy: 0.9358
# Epoch 198/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.9049 - val_loss: 0.2300 - val_sparse_categorical_accuracy: 0.9434
# Epoch 199/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2803 - sparse_categorical_accuracy: 0.9113 - val_loss: 0.1905 - val_sparse_categorical_accuracy: 0.9547
# Epoch 200/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2922 - sparse_categorical_accuracy: 0.9088 - val_loss: 0.2444 - val_sparse_categorical_accuracy: 0.9396
# Epoch 201/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2872 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.2299 - val_sparse_categorical_accuracy: 0.9358
# Epoch 202/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2904 - sparse_categorical_accuracy: 0.9077 - val_loss: 0.2434 - val_sparse_categorical_accuracy: 0.9396
# Epoch 203/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2908 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.2358 - val_sparse_categorical_accuracy: 0.9396
# Epoch 204/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2957 - sparse_categorical_accuracy: 0.9056 - val_loss: 0.2440 - val_sparse_categorical_accuracy: 0.9396
# Epoch 205/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2908 - sparse_categorical_accuracy: 0.9084 - val_loss: 0.2488 - val_sparse_categorical_accuracy: 0.9358
# Epoch 206/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2818 - sparse_categorical_accuracy: 0.9078 - val_loss: 0.2551 - val_sparse_categorical_accuracy: 0.9396
# Epoch 207/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2748 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.2665 - val_sparse_categorical_accuracy: 0.9283
# Epoch 208/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2791 - sparse_categorical_accuracy: 0.9133 - val_loss: 0.2543 - val_sparse_categorical_accuracy: 0.9321
# Epoch 209/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2739 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.2430 - val_sparse_categorical_accuracy: 0.9321
# Epoch 210/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2872 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.2169 - val_sparse_categorical_accuracy: 0.9321
# Epoch 211/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2924 - sparse_categorical_accuracy: 0.9071 - val_loss: 0.2108 - val_sparse_categorical_accuracy: 0.9396
# Epoch 212/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2806 - sparse_categorical_accuracy: 0.9145 - val_loss: 0.2426 - val_sparse_categorical_accuracy: 0.9283
# Epoch 213/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2886 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.2184 - val_sparse_categorical_accuracy: 0.9472
# Epoch 214/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2932 - sparse_categorical_accuracy: 0.9117 - val_loss: 0.2407 - val_sparse_categorical_accuracy: 0.9321
# Epoch 215/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2924 - sparse_categorical_accuracy: 0.9070 - val_loss: 0.2359 - val_sparse_categorical_accuracy: 0.9396
# Epoch 216/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2920 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.2297 - val_sparse_categorical_accuracy: 0.9358
# Epoch 217/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2827 - sparse_categorical_accuracy: 0.9121 - val_loss: 0.2356 - val_sparse_categorical_accuracy: 0.9358
# Epoch 218/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2699 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.2547 - val_sparse_categorical_accuracy: 0.9396
# Epoch 219/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2767 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.2473 - val_sparse_categorical_accuracy: 0.9245
# Epoch 220/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2737 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.2499 - val_sparse_categorical_accuracy: 0.9358
# Epoch 221/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2940 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.2467 - val_sparse_categorical_accuracy: 0.9321
# Epoch 222/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2693 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.2341 - val_sparse_categorical_accuracy: 0.9358
# Epoch 223/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2846 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.2709 - val_sparse_categorical_accuracy: 0.9321
# Epoch 224/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2636 - sparse_categorical_accuracy: 0.9157 - val_loss: 0.2414 - val_sparse_categorical_accuracy: 0.9358
# Epoch 225/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2762 - sparse_categorical_accuracy: 0.9134 - val_loss: 0.2407 - val_sparse_categorical_accuracy: 0.9358
# Epoch 226/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2751 - sparse_categorical_accuracy: 0.9151 - val_loss: 0.2445 - val_sparse_categorical_accuracy: 0.9358
# Epoch 227/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2690 - sparse_categorical_accuracy: 0.9191 - val_loss: 0.2465 - val_sparse_categorical_accuracy: 0.9321
# Epoch 228/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2676 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.2343 - val_sparse_categorical_accuracy: 0.9509
# Epoch 229/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2622 - sparse_categorical_accuracy: 0.9179 - val_loss: 0.2227 - val_sparse_categorical_accuracy: 0.9396
# Epoch 230/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2792 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.2158 - val_sparse_categorical_accuracy: 0.9434
# Epoch 231/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2803 - sparse_categorical_accuracy: 0.9105 - val_loss: 0.2185 - val_sparse_categorical_accuracy: 0.9472
# Epoch 232/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2753 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.2322 - val_sparse_categorical_accuracy: 0.9396
# Epoch 233/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2564 - sparse_categorical_accuracy: 0.9183 - val_loss: 0.2612 - val_sparse_categorical_accuracy: 0.9434
# Epoch 234/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2711 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.2723 - val_sparse_categorical_accuracy: 0.9321
# Epoch 235/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2765 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.2632 - val_sparse_categorical_accuracy: 0.9396
# Epoch 236/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2648 - sparse_categorical_accuracy: 0.9179 - val_loss: 0.2453 - val_sparse_categorical_accuracy: 0.9434
# Epoch 237/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2900 - sparse_categorical_accuracy: 0.9096 - val_loss: 0.2125 - val_sparse_categorical_accuracy: 0.9472
# Epoch 238/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2611 - sparse_categorical_accuracy: 0.9162 - val_loss: 0.2145 - val_sparse_categorical_accuracy: 0.9472
# Epoch 239/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2755 - sparse_categorical_accuracy: 0.9134 - val_loss: 0.2162 - val_sparse_categorical_accuracy: 0.9396
# Epoch 240/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.2673 - sparse_categorical_accuracy: 0.9170 - val_loss: 0.2360 - val_sparse_categorical_accuracy: 0.9358
# Epoch 241/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2595 - sparse_categorical_accuracy: 0.9183 - val_loss: 0.2097 - val_sparse_categorical_accuracy: 0.9509
# Epoch 242/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2621 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.2109 - val_sparse_categorical_accuracy: 0.9509
# Epoch 243/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2696 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.2051 - val_sparse_categorical_accuracy: 0.9547
# Epoch 244/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2551 - sparse_categorical_accuracy: 0.9213 - val_loss: 0.2130 - val_sparse_categorical_accuracy: 0.9547
# Epoch 245/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2695 - sparse_categorical_accuracy: 0.9192 - val_loss: 0.2188 - val_sparse_categorical_accuracy: 0.9472
# Epoch 246/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2635 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.2464 - val_sparse_categorical_accuracy: 0.9434
# Epoch 247/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2670 - sparse_categorical_accuracy: 0.9197 - val_loss: 0.2456 - val_sparse_categorical_accuracy: 0.9472
# Epoch 248/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2813 - sparse_categorical_accuracy: 0.9132 - val_loss: 0.2587 - val_sparse_categorical_accuracy: 0.9358
# Epoch 249/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2604 - sparse_categorical_accuracy: 0.9206 - val_loss: 0.2247 - val_sparse_categorical_accuracy: 0.9472
# Epoch 250/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2621 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.2177 - val_sparse_categorical_accuracy: 0.9434
# Epoch 251/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2748 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.2579 - val_sparse_categorical_accuracy: 0.9321
# Epoch 252/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.2715 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.2176 - val_sparse_categorical_accuracy: 0.9358
# Epoch 253/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2674 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.2255 - val_sparse_categorical_accuracy: 0.9396
# Epoch 254/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2580 - sparse_categorical_accuracy: 0.9182 - val_loss: 0.2051 - val_sparse_categorical_accuracy: 0.9509
# Epoch 255/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2545 - sparse_categorical_accuracy: 0.9193 - val_loss: 0.2102 - val_sparse_categorical_accuracy: 0.9358
# Epoch 256/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2674 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.2168 - val_sparse_categorical_accuracy: 0.9472
# Epoch 257/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2542 - sparse_categorical_accuracy: 0.9206 - val_loss: 0.2480 - val_sparse_categorical_accuracy: 0.9358
# Epoch 258/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2591 - sparse_categorical_accuracy: 0.9191 - val_loss: 0.2100 - val_sparse_categorical_accuracy: 0.9434
# Epoch 259/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2701 - sparse_categorical_accuracy: 0.9176 - val_loss: 0.2946 - val_sparse_categorical_accuracy: 0.9245
# Epoch 260/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2739 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.2211 - val_sparse_categorical_accuracy: 0.9472
# Epoch 261/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2546 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.2233 - val_sparse_categorical_accuracy: 0.9434
# Epoch 262/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2703 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.2361 - val_sparse_categorical_accuracy: 0.9472
# Epoch 263/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2567 - sparse_categorical_accuracy: 0.9185 - val_loss: 0.2316 - val_sparse_categorical_accuracy: 0.9434
# Epoch 264/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2608 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.2249 - val_sparse_categorical_accuracy: 0.9396
# Epoch 265/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2717 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.1980 - val_sparse_categorical_accuracy: 0.9472
# Epoch 266/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2686 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.2253 - val_sparse_categorical_accuracy: 0.9472
# Epoch 267/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2429 - sparse_categorical_accuracy: 0.9225 - val_loss: 0.1936 - val_sparse_categorical_accuracy: 0.9585
# Epoch 268/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2570 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.2326 - val_sparse_categorical_accuracy: 0.9472
# Epoch 269/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2573 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.2288 - val_sparse_categorical_accuracy: 0.9434
# Epoch 270/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2558 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.2339 - val_sparse_categorical_accuracy: 0.9472
# Epoch 271/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2666 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.2517 - val_sparse_categorical_accuracy: 0.9434
# Epoch 272/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2681 - sparse_categorical_accuracy: 0.9200 - val_loss: 0.2879 - val_sparse_categorical_accuracy: 0.9321
# Epoch 273/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2393 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.2349 - val_sparse_categorical_accuracy: 0.9472
# Epoch 274/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2500 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.2589 - val_sparse_categorical_accuracy: 0.9358
# Epoch 275/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2625 - sparse_categorical_accuracy: 0.9178 - val_loss: 0.2185 - val_sparse_categorical_accuracy: 0.9472
# Epoch 276/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2434 - sparse_categorical_accuracy: 0.9213 - val_loss: 0.2682 - val_sparse_categorical_accuracy: 0.9396
# Epoch 277/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2602 - sparse_categorical_accuracy: 0.9227 - val_loss: 0.2466 - val_sparse_categorical_accuracy: 0.9434
# Epoch 278/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2767 - sparse_categorical_accuracy: 0.9149 - val_loss: 0.2125 - val_sparse_categorical_accuracy: 0.9509
# Epoch 279/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2629 - sparse_categorical_accuracy: 0.9188 - val_loss: 0.2293 - val_sparse_categorical_accuracy: 0.9472
# Epoch 280/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2563 - sparse_categorical_accuracy: 0.9225 - val_loss: 0.2310 - val_sparse_categorical_accuracy: 0.9509
# Epoch 281/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2597 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.2458 - val_sparse_categorical_accuracy: 0.9434
# Epoch 282/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2378 - sparse_categorical_accuracy: 0.9237 - val_loss: 0.2938 - val_sparse_categorical_accuracy: 0.9358
# Epoch 283/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2477 - sparse_categorical_accuracy: 0.9237 - val_loss: 0.2695 - val_sparse_categorical_accuracy: 0.9358
# Epoch 284/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2449 - sparse_categorical_accuracy: 0.9212 - val_loss: 0.4406 - val_sparse_categorical_accuracy: 0.8792
# Epoch 285/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2485 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.2096 - val_sparse_categorical_accuracy: 0.9434
# Epoch 286/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2514 - sparse_categorical_accuracy: 0.9222 - val_loss: 0.2179 - val_sparse_categorical_accuracy: 0.9434
# Epoch 287/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2646 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.2146 - val_sparse_categorical_accuracy: 0.9509
# Epoch 288/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2473 - sparse_categorical_accuracy: 0.9216 - val_loss: 0.2204 - val_sparse_categorical_accuracy: 0.9472
# Epoch 289/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.2426 - sparse_categorical_accuracy: 0.9251 - val_loss: 0.2293 - val_sparse_categorical_accuracy: 0.9434
# Epoch 290/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2246 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.2246 - val_sparse_categorical_accuracy: 0.9509
# Epoch 291/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2491 - sparse_categorical_accuracy: 0.9239 - val_loss: 0.1943 - val_sparse_categorical_accuracy: 0.9585
# Epoch 292/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2505 - sparse_categorical_accuracy: 0.9195 - val_loss: 0.2096 - val_sparse_categorical_accuracy: 0.9472
# Epoch 293/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2556 - sparse_categorical_accuracy: 0.9200 - val_loss: 0.2032 - val_sparse_categorical_accuracy: 0.9509
# Epoch 294/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2455 - sparse_categorical_accuracy: 0.9209 - val_loss: 0.2156 - val_sparse_categorical_accuracy: 0.9472
# Epoch 295/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2550 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.2432 - val_sparse_categorical_accuracy: 0.9472
# Epoch 296/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.2407 - sparse_categorical_accuracy: 0.9264 - val_loss: 0.1962 - val_sparse_categorical_accuracy: 0.9547
# Epoch 297/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2523 - sparse_categorical_accuracy: 0.9222 - val_loss: 0.2482 - val_sparse_categorical_accuracy: 0.9509
# Epoch 298/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2445 - sparse_categorical_accuracy: 0.9238 - val_loss: 0.2106 - val_sparse_categorical_accuracy: 0.9509
# Epoch 299/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2493 - sparse_categorical_accuracy: 0.9227 - val_loss: 0.2145 - val_sparse_categorical_accuracy: 0.9585
# Epoch 300/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2365 - sparse_categorical_accuracy: 0.9248 - val_loss: 0.2019 - val_sparse_categorical_accuracy: 0.9472
# Epoch 301/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2504 - sparse_categorical_accuracy: 0.9216 - val_loss: 0.2079 - val_sparse_categorical_accuracy: 0.9472
# Epoch 302/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2533 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.2117 - val_sparse_categorical_accuracy: 0.9434
# Epoch 303/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.2460 - sparse_categorical_accuracy: 0.9229 - val_loss: 0.2029 - val_sparse_categorical_accuracy: 0.9472
# Epoch 304/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2531 - sparse_categorical_accuracy: 0.9212 - val_loss: 0.2143 - val_sparse_categorical_accuracy: 0.9434
# Epoch 305/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2399 - sparse_categorical_accuracy: 0.9265 - val_loss: 0.2318 - val_sparse_categorical_accuracy: 0.9509
# Epoch 306/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2370 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.2464 - val_sparse_categorical_accuracy: 0.9472
# Epoch 307/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2603 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.2169 - val_sparse_categorical_accuracy: 0.9623
# Epoch 308/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2232 - sparse_categorical_accuracy: 0.9293 - val_loss: 0.2038 - val_sparse_categorical_accuracy: 0.9472
# Epoch 309/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2469 - sparse_categorical_accuracy: 0.9242 - val_loss: 0.2082 - val_sparse_categorical_accuracy: 0.9434
# Epoch 310/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2483 - sparse_categorical_accuracy: 0.9229 - val_loss: 0.2459 - val_sparse_categorical_accuracy: 0.9434
# Epoch 311/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2225 - sparse_categorical_accuracy: 0.9314 - val_loss: 0.2218 - val_sparse_categorical_accuracy: 0.9396
# Epoch 312/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2443 - sparse_categorical_accuracy: 0.9259 - val_loss: 0.2139 - val_sparse_categorical_accuracy: 0.9472
# Epoch 313/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2472 - sparse_categorical_accuracy: 0.9254 - val_loss: 0.2133 - val_sparse_categorical_accuracy: 0.9472
# Epoch 314/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.2542 - sparse_categorical_accuracy: 0.9212 - val_loss: 0.2084 - val_sparse_categorical_accuracy: 0.9434
# Epoch 315/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2416 - sparse_categorical_accuracy: 0.9248 - val_loss: 0.2073 - val_sparse_categorical_accuracy: 0.9547
# Epoch 316/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2459 - sparse_categorical_accuracy: 0.9248 - val_loss: 0.2015 - val_sparse_categorical_accuracy: 0.9509
# Epoch 317/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2362 - sparse_categorical_accuracy: 0.9255 - val_loss: 0.2068 - val_sparse_categorical_accuracy: 0.9509
# Epoch 318/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2341 - sparse_categorical_accuracy: 0.9231 - val_loss: 0.1922 - val_sparse_categorical_accuracy: 0.9509
# Epoch 319/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2349 - sparse_categorical_accuracy: 0.9269 - val_loss: 0.1991 - val_sparse_categorical_accuracy: 0.9434
# Epoch 320/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2551 - sparse_categorical_accuracy: 0.9216 - val_loss: 0.2147 - val_sparse_categorical_accuracy: 0.9472
# Epoch 321/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.2441 - sparse_categorical_accuracy: 0.9218 - val_loss: 0.2200 - val_sparse_categorical_accuracy: 0.9472
# Epoch 322/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2475 - sparse_categorical_accuracy: 0.9239 - val_loss: 0.2262 - val_sparse_categorical_accuracy: 0.9358
# Epoch 323/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2430 - sparse_categorical_accuracy: 0.9224 - val_loss: 0.2078 - val_sparse_categorical_accuracy: 0.9472
# Epoch 324/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2322 - sparse_categorical_accuracy: 0.9263 - val_loss: 0.2269 - val_sparse_categorical_accuracy: 0.9509
# Epoch 325/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2337 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.2066 - val_sparse_categorical_accuracy: 0.9472
# Epoch 326/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2298 - sparse_categorical_accuracy: 0.9269 - val_loss: 0.2335 - val_sparse_categorical_accuracy: 0.9509
# Epoch 327/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2217 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.2070 - val_sparse_categorical_accuracy: 0.9396
# Epoch 328/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2450 - sparse_categorical_accuracy: 0.9224 - val_loss: 0.2182 - val_sparse_categorical_accuracy: 0.9434
# Epoch 329/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2395 - sparse_categorical_accuracy: 0.9272 - val_loss: 0.2128 - val_sparse_categorical_accuracy: 0.9472
# Epoch 330/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2383 - sparse_categorical_accuracy: 0.9224 - val_loss: 0.2386 - val_sparse_categorical_accuracy: 0.9245
# Epoch 331/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9254 - val_loss: 0.2078 - val_sparse_categorical_accuracy: 0.9509
# Epoch 332/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2374 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.2135 - val_sparse_categorical_accuracy: 0.9472
# Epoch 333/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2403 - sparse_categorical_accuracy: 0.9244 - val_loss: 0.2149 - val_sparse_categorical_accuracy: 0.9509
# Epoch 334/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2321 - sparse_categorical_accuracy: 0.9275 - val_loss: 0.2275 - val_sparse_categorical_accuracy: 0.9472
# Epoch 335/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2309 - sparse_categorical_accuracy: 0.9277 - val_loss: 0.2158 - val_sparse_categorical_accuracy: 0.9509
# Epoch 336/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2245 - sparse_categorical_accuracy: 0.9305 - val_loss: 0.2118 - val_sparse_categorical_accuracy: 0.9396
# Epoch 337/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2267 - sparse_categorical_accuracy: 0.9285 - val_loss: 0.1974 - val_sparse_categorical_accuracy: 0.9547
# Epoch 338/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2347 - sparse_categorical_accuracy: 0.9244 - val_loss: 0.2459 - val_sparse_categorical_accuracy: 0.9396
# Epoch 339/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2292 - sparse_categorical_accuracy: 0.9284 - val_loss: 0.2005 - val_sparse_categorical_accuracy: 0.9472
# Epoch 340/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2361 - sparse_categorical_accuracy: 0.9268 - val_loss: 0.2211 - val_sparse_categorical_accuracy: 0.9472
# Epoch 341/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2358 - sparse_categorical_accuracy: 0.9263 - val_loss: 0.2267 - val_sparse_categorical_accuracy: 0.9623
# Epoch 342/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.2369 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.1893 - val_sparse_categorical_accuracy: 0.9623
# Epoch 343/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2372 - sparse_categorical_accuracy: 0.9265 - val_loss: 0.2137 - val_sparse_categorical_accuracy: 0.9396
# Epoch 344/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9250 - val_loss: 0.1941 - val_sparse_categorical_accuracy: 0.9509
# Epoch 345/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2309 - sparse_categorical_accuracy: 0.9306 - val_loss: 0.2067 - val_sparse_categorical_accuracy: 0.9434
# Epoch 346/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.2294 - sparse_categorical_accuracy: 0.9296 - val_loss: 0.2227 - val_sparse_categorical_accuracy: 0.9509
# Epoch 347/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2234 - sparse_categorical_accuracy: 0.9317 - val_loss: 0.2173 - val_sparse_categorical_accuracy: 0.9396
# Epoch 348/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2238 - sparse_categorical_accuracy: 0.9273 - val_loss: 0.2126 - val_sparse_categorical_accuracy: 0.9472
# Epoch 349/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2356 - sparse_categorical_accuracy: 0.9277 - val_loss: 0.2488 - val_sparse_categorical_accuracy: 0.9509
# Epoch 350/350
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2378 - sparse_categorical_accuracy: 0.9265 - val_loss: 0.2401 - val_sparse_categorical_accuracy: 0.9396

# %% [markdown]
# # Evaluación del modelo
#
# La evolución del modelo es lenta y el error de validación no baja, lo que indica sobre ajuste.

# %%
loss = hist.history["loss"]
val_loss = hist.history["val_loss"]

plt.plot(loss, label="loss")
plt.plot(val_loss, label="val_loss")
plt.title("Loss")
plt.legend()
plt.show()

# %% [markdown]
# El acc del conjunto de validación no crece.

# %%
acc = hist.history["sparse_categorical_accuracy"]
val_acc = hist.history["val_sparse_categorical_accuracy"]

plt.plot(acc, label="acc")
plt.plot(val_acc, label="val_acc")
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# Aquí podemos ver que el modelo solo funciona bien en el conjunto de entrenamiento, lo que demuestra el sobreajuste.

# %%
train_loss, train_acc = model.evaluate(X_train, y_train_num, verbose=0)
val_loss, val_acc = model.evaluate(X_val, y_val_num, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test_num, verbose=0)

print("TRAIN:")
print("Loss:", round(train_loss,3))
print("Accuracy:", round(train_acc,3))

print("\nVALIDATION:")
print("Loss:", round(val_loss,3))
print("Accuracy:", round(val_acc,3))

print("\nTEST:")
print("Loss:", round(test_loss,3))
print("Accuracy:", round(test_acc,3))
# Out:
# TRAIN:
# Loss: 0.048
# Accuracy: 0.989
#
# VALIDATION:
# Loss: 0.24
# Accuracy: 0.94
#
# TEST:
# Loss: 0.38
# Accuracy: 0.909

# %% [markdown]
# # Matriz de confución
#
# Aquí podemos ver la matriz de confución del modelo y funciona como se espera.

# %%
class_names = encoder.classes_

cm = confusion_matrix(y_test_num, np.argmax(model.predict(X_test), axis=1), normalize="true")

plt.figure(figsize=(20, 20))
sns.heatmap(cm,
            annot=True, cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names,
            cbar=True)

plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.title('Matriz de Confusión')
plt.yticks(rotation=0)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# # Conclusión
#
# El modelo aun parece tener margen de mejora, el proximo paso podría ser añadir más capas o incluso regularizar un poco más.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def cargar_img_individual(num,path, size=(75, 75)):
    img = cv2.imread(path)
    im2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(im2)
    plt.show()
    if img is None:
        raise ValueError(f"No se pudo cargar la imagen: {path}")

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)[0:num, 0:num]
    img_resize = cv2.resize(img_rgb, size)
    img_norm = img_resize / 255.0

    return img_norm

def predecir_imagen(num,path, model, encoder, size=(75, 75), mostrar=True):
    # Preprocesado
    img = cargar_img_individual(num,path, size)

    # Añadir dimensión batch: (75,75,3) -> (1,75,75,3)
    img_batch = np.expand_dims(img, axis=0)

    # Predicción
    pred = model.predict(img_batch, verbose=0)
    clase_idx = np.argmax(pred, axis=1)[0]
    clase_nombre = encoder.inverse_transform([clase_idx])[0]
    confianza = pred[0][clase_idx]

    if mostrar:
        plt.imshow(img)
        plt.title(f"Predicción: {clase_nombre} | Confianza: {confianza:.4f}")
        plt.axis("off")
        plt.show()

    return clase_nombre, confianza, pred[0]

# %%
ruta_prueba = "ace3.png"
clase, confianza, probabilidades = predecir_imagen(250,ruta_prueba, model, encoder)

print("Clase predicha:", clase)
print("Confianza:", confianza)
# Out:
# Clase predicha: ace of hearts
# Confianza: 0.7401817

# %%
ruta_prueba = "8ofspades.png"
clase, confianza, probabilidades = predecir_imagen(220,ruta_prueba, model, encoder)

print("Clase predicha:", clase)
print("Confianza:", confianza)
# Out:
# Clase predicha: eight of spades
# Confianza: 0.9937724

# %%
ruta_prueba = "8ofclubs.png"
clase, confianza, probabilidades = predecir_imagen(220,ruta_prueba, model, encoder)

print("Clase predicha:", clase)
print("Confianza:", confianza)
# Out:
# Clase predicha: eight of clubs
# Confianza: 0.9722066

# %%
ruta_prueba = "8ofhearts.png"
clase, confianza, probabilidades = predecir_imagen(70,ruta_prueba, model, encoder)

print("Clase predicha:", clase)
print("Confianza:", confianza)
# Out:
# Clase predicha: eight of hearts
# Confianza: 0.9703799

# %%
ruta_prueba = "acespade.png"
clase, confianza, probabilidades = predecir_imagen(151,ruta_prueba, model, encoder)

print("Clase predicha:", clase)
print("Confianza:", confianza)
# Out:
# Clase predicha: ace of spades
# Confianza: 0.25622448

# %%
ruta_prueba = "fourofspades.png"
clase, confianza, probabilidades = predecir_imagen(151,ruta_prueba, model, encoder)

print("Clase predicha:", clase)
print("Confianza:", confianza)
# Out:
# Clase predicha: four of spades
# Confianza: 0.995625

# %%
ruta_prueba = "sixofspades.png"
clase, confianza, probabilidades = predecir_imagen(151,ruta_prueba, model, encoder)

print("Clase predicha:", clase)
print("Confianza:", confianza)
# Out:
# Clase predicha: six of spades
# Confianza: 0.5134257

# %%
ruta_prueba = rutas_test.iloc[0]
clase, confianza, probabilidades = predecir_imagen(ruta_prueba, model, encoder)
print("Etiqueta real:", y_test.iloc[0])
print("Predicción:", clase)
# Out:
# Etiqueta real: ace of clubs
# Predicción: queen of spades

# %%
for i in range(5):
    ruta = rutas_test.iloc[i]
    real = y_test.iloc[i]
    predicha, confianza, _ = predecir_imagen(ruta, model, encoder, mostrar=True)
    print(f"Real: {real} | Predicha: {predicha} | Confianza: {confianza:.4f}")
# Out:
# Real: ace of clubs | Predicha: queen of spades | Confianza: 0.2009
# Real: ace of clubs | Predicha: two of clubs | Confianza: 0.4412
# Real: ace of clubs | Predicha: ten of clubs | Confianza: 0.3812
# Real: ace of clubs | Predicha: ten of clubs | Confianza: 0.7648
# Real: ace of clubs | Predicha: ace of spades | Confianza: 0.2135

# %% [markdown]
# Shorter for one image

# %%
path = rutas_test.iloc[0]

img = cargar_img_individual(path, (75, 75))
pred = model.predict(np.expand_dims(img, axis=0), verbose=0)
idx = np.argmax(pred, axis=1)[0]
label = encoder.inverse_transform([idx])[0]

print("Predicción:", label)
plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# Predicción: queen of spades
