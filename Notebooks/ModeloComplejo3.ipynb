# %% [markdown]
# <font color="FF3B3B"><h1 align="left">Proyecto de aprendizaje profundo</h1></font>
# <font color="#6E6E6E"><h2 align="left">Modelo complejo CNN Nº 3</h2></font>
#
# ##### David Alejandro Pedroza De Jesús
# ##### Joel Ezequiel Vicente Alonso
#
# Cargamos las librerias para la realización del proyecto

# %%
import sys
sys.path.append("../")
from modelos.CNNComplejo3 import ModeloComplejo
import numpy as np
import pandas as pd
import cv2
import kagglehub
import os
from shutil import move
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns
from tensorflow.keras.utils import plot_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#      10 import matplotlib.pyplot as plt
#      11 import tensorflow as tf
# ---> 12 from sklearn.preprocessing import LabelEncoder
#      13 from sklearn.metrics import confusion_matrix
#      14 import seaborn as sns
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# # Cargar las imagenes
#
# Hararemos el procesado que hemos hecho antes, tanto con las etiquetas e imagenes.

# %%
path = kagglehub.dataset_download("gpiosenka/cards-image-datasetclassification")
print(path)
# Out:
# Using Colab cache for faster access to the 'cards-image-datasetclassification' dataset.
# /kaggle/input/cards-image-datasetclassification

# %%
move(path,os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     846     try:
# --> 847         os.rename(src, real_dst)
#     848     except OSError:
#
# OSError: [Errno 18] Invalid cross-device link: '/kaggle/input/cards-image-datasetclassification' -> '/content/cards-image-datasetclassification'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_278/3271023425.py in <cell line: 0>()
# ----> 1 move(path,os.getcwd())
#
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     863             copytree(src, real_dst, copy_function=copy_function,
#     864                      symlinks=True)
# --> 865             rmtree(src)
#     866         else:
#     867             copy_function(src, real_dst)
#
# /usr/lib/python3.12/shutil.py in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     757         try:
#     758             while stack:
# --> 759                 _rmtree_safe_fd(stack, onexc)
#     760         finally:
#     761             # Close any file descriptors still on the stack.
#
# /usr/lib/python3.12/shutil.py in _rmtree_safe_fd(stack, onexc)
#     701     except OSError as err:
#     702         err.filename = path
# --> 703         onexc(func, path, err)
#     704
#     705 _use_fd_functions = ({os.open, os.stat, os.unlink, os.rmdir} <=
#
# /usr/lib/python3.12/shutil.py in _rmtree_safe_fd(stack, onexc)
#     698                 os.unlink(entry.name, dir_fd=topfd)
#     699             except OSError as err:
# --> 700                 onexc(os.unlink, fullname, err)
#     701     except OSError as err:
#     702         err.filename = path
#
# /usr/lib/python3.12/shutil.py in _rmtree_safe_fd(stack, onexc)
#     696                 pass
#     697             try:
# --> 698                 os.unlink(entry.name, dir_fd=topfd)
#     699             except OSError as err:
#     700                 onexc(os.unlink, fullname, err)
#
# OSError: [Errno 30] Read-only file system: '/kaggle/input/cards-image-datasetclassification'

# %%
os.rename("2","cards-image-datasetclassification")

# %%
datos = pd.read_csv(r"cards-image-datasetclassification/cards.csv")
datos.head()
# Out:
#    class index                   filepaths        labels card type data set
# 0            0  train/ace of clubs/001.jpg  ace of clubs       ace    train
# 1            0  train/ace of clubs/002.jpg  ace of clubs       ace    train
# 2            0  train/ace of clubs/003.jpg  ace of clubs       ace    train
# 3            0  train/ace of clubs/004.jpg  ace of clubs       ace    train
# 4            0  train/ace of clubs/005.jpg  ace of clubs       ace    train

# %% [markdown]
# Arreglamos las rutas.

# %%
rutas_adaptadas = ["cards-image-datasetclassification/" +  ruta for ruta in datos["filepaths"]]
im_buenas = []
im_malas = []
for ru in rutas_adaptadas:
    im = cv2.imread(ru)
    if  im is not None:
        im_buenas.append(ru)
    else:
        im_malas.append(ru)
#print(f"Lecturas correctas: {len(im_buenas)}")
#print(f"Lecturas incorrectas: {len(im_malas)}")

df_limpio = datos[np.array(rutas_adaptadas) != np.array(im_malas)]
df_limpio["rutas_adap"] = im_buenas
# Out:
# /tmp/ipykernel_278/1813950221.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["rutas_adap"] = im_buenas

# %% [markdown]
# Ahora cargamos las imagenes, añadiremos un procesado más, debido a que no necesitamos toda la carta para realizar la predicción.

# %%
def CargarImg(path, size):
    img = cv2.imread(path)
    img_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)[0:75,0:75]#De con esto ya tenemos toda la información
    img_resize = cv2.resize(img_RGB, size)
    return np.array(img_resize / 255.)

# %%
rutas_train = df_limpio[df_limpio["data set"] == "train"].rutas_adap
rutas_test = df_limpio[df_limpio["data set"] == "test"].rutas_adap
rutas_val = df_limpio[df_limpio["data set"] == "valid"].rutas_adap

X_train = np.array([CargarImg(path, (75, 75)) for path in rutas_train])
X_test = np.array([CargarImg(path, (75, 75)) for path in rutas_test])
X_val = np.array([CargarImg(path, (75, 75)) for path in rutas_val])

y_train = df_limpio[df_limpio["data set"] == "train"]["labels"]
y_test = df_limpio[df_limpio["data set"] == "test"]["labels"]
y_val = df_limpio[df_limpio["data set"] == "valid"]["labels"]

# %% [markdown]
# Y codificamos los labels con `LabelEncoder()`

# %%
encoder = LabelEncoder()

y_train_num = encoder.fit_transform(y_train)
y_val_num   = encoder.transform(y_val)
y_test_num  = encoder.transform(y_test)

# %% [markdown]
# # Arquitectura de la red
#
# En este apartado iremos probando la arquitectura, en este hemos añadido capas dos capas dense y dos capas convolucionales.

# %%
input_shape = X_train[0].shape
num_clases = np.unique(y_train_num).shape[0]
model = ModeloComplejo(input_shape, num_clases)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 75, 75, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 75, 75, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 37, 37, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 37, 37, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 18, 18, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 18, 18, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 18, 18, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 18, 18, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10368)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,654,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 53)             │        13,621 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,762,229 (10.54 MB)
#  Trainable params: 2,761,781 (10.54 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# También aquí hacemos un plot de la arquitectura del modelo.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# # Entrenamiento
#
# En este apartado realizaremos el entrenamiento.

# %%
hist = model.fit(X_train, y_train_num,validation_data=(X_val, y_val_num), epochs=50)
# Out:
# Epoch 1/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - loss: 4.7797 - sparse_categorical_accuracy: 0.0213 - val_loss: 3.9705 - val_sparse_categorical_accuracy: 0.0189
# Epoch 2/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9683 - sparse_categorical_accuracy: 0.0229 - val_loss: 3.9710 - val_sparse_categorical_accuracy: 0.0189
# Epoch 3/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9669 - sparse_categorical_accuracy: 0.0222 - val_loss: 3.9716 - val_sparse_categorical_accuracy: 0.0189
# Epoch 4/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9654 - sparse_categorical_accuracy: 0.0241 - val_loss: 3.9723 - val_sparse_categorical_accuracy: 0.0189
# Epoch 5/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9640 - sparse_categorical_accuracy: 0.0217 - val_loss: 3.9729 - val_sparse_categorical_accuracy: 0.0189
# Epoch 6/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9642 - sparse_categorical_accuracy: 0.0209 - val_loss: 3.9735 - val_sparse_categorical_accuracy: 0.0189
# Epoch 7/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9625 - sparse_categorical_accuracy: 0.0223 - val_loss: 3.9741 - val_sparse_categorical_accuracy: 0.0189
# Epoch 8/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9644 - sparse_categorical_accuracy: 0.0233 - val_loss: 3.9746 - val_sparse_categorical_accuracy: 0.0189
# Epoch 9/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9646 - sparse_categorical_accuracy: 0.0239 - val_loss: 3.9751 - val_sparse_categorical_accuracy: 0.0189
# Epoch 10/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9651 - sparse_categorical_accuracy: 0.0210 - val_loss: 3.9754 - val_sparse_categorical_accuracy: 0.0189
# Epoch 11/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9627 - sparse_categorical_accuracy: 0.0237 - val_loss: 3.9757 - val_sparse_categorical_accuracy: 0.0189
# Epoch 12/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9639 - sparse_categorical_accuracy: 0.0250 - val_loss: 3.9760 - val_sparse_categorical_accuracy: 0.0189
# Epoch 13/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9615 - sparse_categorical_accuracy: 0.0239 - val_loss: 3.9762 - val_sparse_categorical_accuracy: 0.0189
# Epoch 14/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9635 - sparse_categorical_accuracy: 0.0224 - val_loss: 3.9764 - val_sparse_categorical_accuracy: 0.0189
# Epoch 15/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9642 - sparse_categorical_accuracy: 0.0230 - val_loss: 3.9766 - val_sparse_categorical_accuracy: 0.0189
# Epoch 16/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 3.9637 - sparse_categorical_accuracy: 0.0234 - val_loss: 3.9768 - val_sparse_categorical_accuracy: 0.0189
# Epoch 17/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9653 - sparse_categorical_accuracy: 0.0241 - val_loss: 3.9769 - val_sparse_categorical_accuracy: 0.0189
# Epoch 18/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9643 - sparse_categorical_accuracy: 0.0232 - val_loss: 3.9771 - val_sparse_categorical_accuracy: 0.0189
# Epoch 19/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9640 - sparse_categorical_accuracy: 0.0253 - val_loss: 3.9772 - val_sparse_categorical_accuracy: 0.0189
# Epoch 20/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9608 - sparse_categorical_accuracy: 0.0243 - val_loss: 3.9772 - val_sparse_categorical_accuracy: 0.0189
# Epoch 21/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 3.9629 - sparse_categorical_accuracy: 0.0276 - val_loss: 3.9773 - val_sparse_categorical_accuracy: 0.0189
# Epoch 22/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9628 - sparse_categorical_accuracy: 0.0208 - val_loss: 3.9773 - val_sparse_categorical_accuracy: 0.0189
# Epoch 23/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9658 - sparse_categorical_accuracy: 0.0222 - val_loss: 3.9774 - val_sparse_categorical_accuracy: 0.0189
# Epoch 24/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9621 - sparse_categorical_accuracy: 0.0235 - val_loss: 3.9774 - val_sparse_categorical_accuracy: 0.0189
# Epoch 25/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9638 - sparse_categorical_accuracy: 0.0252 - val_loss: 3.9775 - val_sparse_categorical_accuracy: 0.0189
# Epoch 26/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 3.9643 - sparse_categorical_accuracy: 0.0244 - val_loss: 3.9775 - val_sparse_categorical_accuracy: 0.0189
# Epoch 27/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9618 - sparse_categorical_accuracy: 0.0255 - val_loss: 3.9775 - val_sparse_categorical_accuracy: 0.0189
# Epoch 28/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9643 - sparse_categorical_accuracy: 0.0236 - val_loss: 3.9775 - val_sparse_categorical_accuracy: 0.0189
# Epoch 29/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9641 - sparse_categorical_accuracy: 0.0239 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 30/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9643 - sparse_categorical_accuracy: 0.0228 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 31/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9623 - sparse_categorical_accuracy: 0.0269 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 32/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9650 - sparse_categorical_accuracy: 0.0256 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 33/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9617 - sparse_categorical_accuracy: 0.0234 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 34/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9648 - sparse_categorical_accuracy: 0.0222 - val_loss: 3.9775 - val_sparse_categorical_accuracy: 0.0189
# Epoch 35/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9640 - sparse_categorical_accuracy: 0.0229 - val_loss: 3.9775 - val_sparse_categorical_accuracy: 0.0189
# Epoch 36/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9644 - sparse_categorical_accuracy: 0.0246 - val_loss: 3.9775 - val_sparse_categorical_accuracy: 0.0189
# Epoch 37/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9637 - sparse_categorical_accuracy: 0.0278 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 38/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9644 - sparse_categorical_accuracy: 0.0259 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 39/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9638 - sparse_categorical_accuracy: 0.0233 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 40/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9647 - sparse_categorical_accuracy: 0.0244 - val_loss: 3.9777 - val_sparse_categorical_accuracy: 0.0189
# Epoch 41/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9623 - sparse_categorical_accuracy: 0.0231 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 42/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 3.9623 - sparse_categorical_accuracy: 0.0253 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 43/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9635 - sparse_categorical_accuracy: 0.0233 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 44/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9640 - sparse_categorical_accuracy: 0.0224 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 45/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9634 - sparse_categorical_accuracy: 0.0255 - val_loss: 3.9777 - val_sparse_categorical_accuracy: 0.0189
# Epoch 46/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.9643 - sparse_categorical_accuracy: 0.0245 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 47/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 3.9636 - sparse_categorical_accuracy: 0.0234 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 48/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9643 - sparse_categorical_accuracy: 0.0220 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 49/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9632 - sparse_categorical_accuracy: 0.0223 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189
# Epoch 50/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9643 - sparse_categorical_accuracy: 0.0230 - val_loss: 3.9776 - val_sparse_categorical_accuracy: 0.0189

# %% [markdown]
# # Evaluación del modelo
#
# En el caso del loss del train vemos que si baja con las epocas y converge, pero con el conjunto validación no ocurre, lo que indica o sobre ajuste o incluso que los datos tienen algo raro.

# %%
loss = hist.history["loss"]
val_loss = hist.history["val_loss"]

plt.plot(loss, label="loss")
plt.plot(val_loss, label="val_loss")
plt.title("Loss")
plt.legend()
plt.show()

# %% [markdown]
# En cuanto el accuracy demuestra que el modelo no esta aprendiendo,

# %%
acc = hist.history["sparse_categorical_accuracy"]
val_acc = hist.history["val_sparse_categorical_accuracy"]

plt.plot(acc, label="acc")
plt.plot(val_acc, label="val_acc")
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# En este caso vemos lo que ya la curvas nos dicen, el modelo tiene poco error en train, pero es muy alto en test y validación.En cuanto al acuraccy nos esta indicando que el modelo no ha aprendido.

# %%
train_loss, train_acc = model.evaluate(X_train, y_train_num, verbose=0)
val_loss, val_acc = model.evaluate(X_val, y_val_num, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test_num, verbose=0)

print("TRAIN:")
print("Loss:", round(train_loss,3))
print("Accuracy:", round(train_acc,3))

print("\nVALIDATION:")
print("Loss:", round(val_loss,3))
print("Accuracy:", round(val_acc,3))

print("\nTEST:")
print("Loss:", round(test_loss,3))
print("Accuracy:", round(test_acc,3))
# Out:
# TRAIN:
# Loss: 3.963
# Accuracy: 0.024
#
# VALIDATION:
# Loss: 3.978
# Accuracy: 0.019
#
# TEST:
# Loss: 3.978
# Accuracy: 0.019

# %% [markdown]
# # Matriz de confución
#
# En cuanto a las predicciones no parece estar tan mal como parece, debido a que al menos tenemos que en casi todos los casos, en la mayoria acierta.

# %%
class_names = encoder.classes_

cm = confusion_matrix(y_test_num, np.argmax(model.predict(X_test), axis=1), normalize="true")

plt.figure(figsize=(20, 20))
sns.heatmap(cm,
            annot=True, cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names,
            cbar=True)

plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.title('Matriz de Confusión')
plt.yticks(rotation=0)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
