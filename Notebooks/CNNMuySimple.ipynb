# %% [markdown]
# <font color="FF3B3B"><h1 align="left">Proyecto de aprendizaje profundo</h1></font>
# <font color="#6E6E6E"><h2 align="left">Modelo de red neuronal simple</h2></font>
#
# ##### David Alejandro Pedroza De Jesús
# ##### Joel Ezequiel Vicente Alonso
#
# Cargamos las librerias para la realización del proyecto

# %%
import sys
sys.path.append("../")
from modelos.RNNMoreSimple import ModeloSimpleCLS
import numpy as np
import pandas as pd
import cv2
import kagglehub
import os
from shutil import move
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # Descarga, carga y limpieza de datos
#
# Aquí como siempre descargamos los datos y lo movemos a la carpeta de trabajo.

# %%
path = kagglehub.dataset_download("gpiosenka/cards-image-datasetclassification")
#move(path,os.getcwd())
# Out:
# Using Colab cache for faster access to the 'cards-image-datasetclassification' dataset.

# %%
#os.rename("2", "cards-image-datasetclassification")

# %%
datos = pd.read_csv(r"cards-image-datasetclassification/cards.csv")
datos.head()
# Out:
#    class index                   filepaths        labels card type data set
# 0            0  train/ace of clubs/001.jpg  ace of clubs       ace    train
# 1            0  train/ace of clubs/002.jpg  ace of clubs       ace    train
# 2            0  train/ace of clubs/003.jpg  ace of clubs       ace    train
# 3            0  train/ace of clubs/004.jpg  ace of clubs       ace    train
# 4            0  train/ace of clubs/005.jpg  ace of clubs       ace    train

# %% [markdown]
# Quitamos las rutas como hemos hecho siempre.

# %%
rutas_adaptadas = ["cards-image-datasetclassification/" +  ruta for ruta in datos["filepaths"]]
im_buenas = []
im_malas = []
for ru in rutas_adaptadas:
    im = cv2.imread(ru)
    if  im is not None:
        im_buenas.append(ru)
    else:
        im_malas.append(ru)
print(f"Lecturas correctas: {len(im_buenas)}")
print(f"Lecturas incorrectas: {len(im_malas)}")

df_limpio = datos[np.array(rutas_adaptadas) != np.array(im_malas)]
df_limpio["rutas_adap"] = im_buenas
# Out:
# Lecturas correctas: 8154
# Lecturas incorrectas: 1
# /tmp/ipykernel_187/4150467203.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["rutas_adap"] = im_buenas

# %% [markdown]
# Ahora creamos una función que normalice y cargue las imagenes, para ello crearemos una función que haga esa función.

# %%
def CargarImg(path, size):
    img = cv2.imread(path)
    img_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_resize = cv2.resize(img_RGB, size)
    return np.array(img_resize / 255.)

# %% [markdown]
# Cargamos los datos necesarios para el entrenamiento.

# %%
rutas_train = df_limpio[df_limpio["data set"] == "train"].rutas_adap
rutas_test = df_limpio[df_limpio["data set"] == "test"].rutas_adap
rutas_val = df_limpio[df_limpio["data set"] == "valid"].rutas_adap

X_train = np.array([CargarImg(path, (128, 128)) for path in rutas_train])
X_test = np.array([CargarImg(path, (128, 128)) for path in rutas_test])
X_val = np.array([CargarImg(path, (128, 128)) for path in rutas_val])

y_train = df_limpio[df_limpio["data set"] == "train"]["labels"]
y_test = df_limpio[df_limpio["data set"] == "test"]["labels"]
y_val = df_limpio[df_limpio["data set"] == "valid"]["labels"]

# %% [markdown]
# Por ultimo codificamos las salidas con laber encoder.

# %%
encoder = LabelEncoder()

y_train_num = encoder.fit_transform(y_train)
y_val_num   = encoder.transform(y_val)
y_test_num  = encoder.transform(y_test)

# %% [markdown]
# # Entrenamiento
#
# Ahora entraremos el modelo simple para ver que resultados tenemos.Primero cargaremos la arquitectura del modelo usando nuestra función de `modelos/RNNSimple.py`.

# %%
model = ModeloSimpleCLS((128, 128, 3), y_train.unique().shape[0])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 126, 126, 53)   │         1,484 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 53)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,484 (5.80 KB)
#  Trainable params: 1,484 (5.80 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Ahora entrenamos nuestro modelo.

# %%
hist = model.fit(X_train, y_train_num,validation_data=(X_val, y_val_num), epochs=200)
# Out:
# Epoch 1/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 3.9763 - sparse_categorical_accuracy: 0.0223 - val_loss: 3.9724 - val_sparse_categorical_accuracy: 0.0302
# Epoch 2/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9686 - sparse_categorical_accuracy: 0.0212 - val_loss: 3.9704 - val_sparse_categorical_accuracy: 0.0226
# Epoch 3/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9666 - sparse_categorical_accuracy: 0.0230 - val_loss: 3.9689 - val_sparse_categorical_accuracy: 0.0226
# Epoch 4/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9667 - sparse_categorical_accuracy: 0.0208 - val_loss: 3.9685 - val_sparse_categorical_accuracy: 0.0226
# Epoch 5/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9643 - sparse_categorical_accuracy: 0.0279 - val_loss: 3.9664 - val_sparse_categorical_accuracy: 0.0264
# Epoch 6/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9632 - sparse_categorical_accuracy: 0.0233 - val_loss: 3.9658 - val_sparse_categorical_accuracy: 0.0226
# Epoch 7/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9615 - sparse_categorical_accuracy: 0.0254 - val_loss: 3.9622 - val_sparse_categorical_accuracy: 0.0340
# Epoch 8/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9612 - sparse_categorical_accuracy: 0.0256 - val_loss: 3.9646 - val_sparse_categorical_accuracy: 0.0340
# Epoch 9/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9609 - sparse_categorical_accuracy: 0.0237 - val_loss: 3.9623 - val_sparse_categorical_accuracy: 0.0302
# Epoch 10/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9585 - sparse_categorical_accuracy: 0.0258 - val_loss: 3.9610 - val_sparse_categorical_accuracy: 0.0302
# Epoch 11/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9583 - sparse_categorical_accuracy: 0.0262 - val_loss: 3.9604 - val_sparse_categorical_accuracy: 0.0264
# Epoch 12/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9571 - sparse_categorical_accuracy: 0.0257 - val_loss: 3.9623 - val_sparse_categorical_accuracy: 0.0189
# Epoch 13/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9545 - sparse_categorical_accuracy: 0.0316 - val_loss: 3.9587 - val_sparse_categorical_accuracy: 0.0264
# Epoch 14/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9551 - sparse_categorical_accuracy: 0.0292 - val_loss: 3.9565 - val_sparse_categorical_accuracy: 0.0340
# Epoch 15/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9536 - sparse_categorical_accuracy: 0.0372 - val_loss: 3.9593 - val_sparse_categorical_accuracy: 0.0226
# Epoch 16/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9533 - sparse_categorical_accuracy: 0.0359 - val_loss: 3.9570 - val_sparse_categorical_accuracy: 0.0340
# Epoch 17/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9506 - sparse_categorical_accuracy: 0.0417 - val_loss: 3.9560 - val_sparse_categorical_accuracy: 0.0226
# Epoch 18/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9507 - sparse_categorical_accuracy: 0.0392 - val_loss: 3.9553 - val_sparse_categorical_accuracy: 0.0226
# Epoch 19/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9497 - sparse_categorical_accuracy: 0.0323 - val_loss: 3.9560 - val_sparse_categorical_accuracy: 0.0189
# Epoch 20/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9519 - sparse_categorical_accuracy: 0.0317 - val_loss: 3.9545 - val_sparse_categorical_accuracy: 0.0226
# Epoch 21/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9486 - sparse_categorical_accuracy: 0.0322 - val_loss: 3.9509 - val_sparse_categorical_accuracy: 0.0302
# Epoch 22/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9433 - sparse_categorical_accuracy: 0.0378 - val_loss: 3.9521 - val_sparse_categorical_accuracy: 0.0302
# Epoch 23/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9438 - sparse_categorical_accuracy: 0.0391 - val_loss: 3.9510 - val_sparse_categorical_accuracy: 0.0340
# Epoch 24/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9447 - sparse_categorical_accuracy: 0.0355 - val_loss: 3.9536 - val_sparse_categorical_accuracy: 0.0302
# Epoch 25/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9454 - sparse_categorical_accuracy: 0.0343 - val_loss: 3.9497 - val_sparse_categorical_accuracy: 0.0340
# Epoch 26/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9432 - sparse_categorical_accuracy: 0.0363 - val_loss: 3.9501 - val_sparse_categorical_accuracy: 0.0264
# Epoch 27/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9402 - sparse_categorical_accuracy: 0.0380 - val_loss: 3.9485 - val_sparse_categorical_accuracy: 0.0415
# Epoch 28/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9397 - sparse_categorical_accuracy: 0.0430 - val_loss: 3.9519 - val_sparse_categorical_accuracy: 0.0302
# Epoch 29/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9406 - sparse_categorical_accuracy: 0.0431 - val_loss: 3.9473 - val_sparse_categorical_accuracy: 0.0340
# Epoch 30/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9411 - sparse_categorical_accuracy: 0.0324 - val_loss: 3.9466 - val_sparse_categorical_accuracy: 0.0302
# Epoch 31/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9429 - sparse_categorical_accuracy: 0.0319 - val_loss: 3.9480 - val_sparse_categorical_accuracy: 0.0415
# Epoch 32/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9367 - sparse_categorical_accuracy: 0.0379 - val_loss: 3.9476 - val_sparse_categorical_accuracy: 0.0264
# Epoch 33/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9381 - sparse_categorical_accuracy: 0.0396 - val_loss: 3.9477 - val_sparse_categorical_accuracy: 0.0189
# Epoch 34/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9382 - sparse_categorical_accuracy: 0.0343 - val_loss: 3.9468 - val_sparse_categorical_accuracy: 0.0377
# Epoch 35/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9324 - sparse_categorical_accuracy: 0.0397 - val_loss: 3.9451 - val_sparse_categorical_accuracy: 0.0415
# Epoch 36/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9355 - sparse_categorical_accuracy: 0.0405 - val_loss: 3.9468 - val_sparse_categorical_accuracy: 0.0340
# Epoch 37/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9337 - sparse_categorical_accuracy: 0.0433 - val_loss: 3.9437 - val_sparse_categorical_accuracy: 0.0340
# Epoch 38/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9314 - sparse_categorical_accuracy: 0.0451 - val_loss: 3.9449 - val_sparse_categorical_accuracy: 0.0302
# Epoch 39/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9318 - sparse_categorical_accuracy: 0.0313 - val_loss: 3.9430 - val_sparse_categorical_accuracy: 0.0415
# Epoch 40/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9314 - sparse_categorical_accuracy: 0.0384 - val_loss: 3.9455 - val_sparse_categorical_accuracy: 0.0340
# Epoch 41/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9281 - sparse_categorical_accuracy: 0.0436 - val_loss: 3.9436 - val_sparse_categorical_accuracy: 0.0340
# Epoch 42/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.9312 - sparse_categorical_accuracy: 0.0397 - val_loss: 3.9427 - val_sparse_categorical_accuracy: 0.0264
# Epoch 43/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9279 - sparse_categorical_accuracy: 0.0378 - val_loss: 3.9431 - val_sparse_categorical_accuracy: 0.0340
# Epoch 44/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9270 - sparse_categorical_accuracy: 0.0434 - val_loss: 3.9435 - val_sparse_categorical_accuracy: 0.0377
# Epoch 45/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9274 - sparse_categorical_accuracy: 0.0447 - val_loss: 3.9441 - val_sparse_categorical_accuracy: 0.0415
# Epoch 46/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9253 - sparse_categorical_accuracy: 0.0360 - val_loss: 3.9409 - val_sparse_categorical_accuracy: 0.0302
# Epoch 47/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9263 - sparse_categorical_accuracy: 0.0430 - val_loss: 3.9428 - val_sparse_categorical_accuracy: 0.0453
# Epoch 48/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9260 - sparse_categorical_accuracy: 0.0418 - val_loss: 3.9408 - val_sparse_categorical_accuracy: 0.0340
# Epoch 49/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9267 - sparse_categorical_accuracy: 0.0461 - val_loss: 3.9403 - val_sparse_categorical_accuracy: 0.0377
# Epoch 50/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9251 - sparse_categorical_accuracy: 0.0432 - val_loss: 3.9420 - val_sparse_categorical_accuracy: 0.0340
# Epoch 51/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9240 - sparse_categorical_accuracy: 0.0389 - val_loss: 3.9397 - val_sparse_categorical_accuracy: 0.0453
# Epoch 52/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9236 - sparse_categorical_accuracy: 0.0473 - val_loss: 3.9418 - val_sparse_categorical_accuracy: 0.0302
# Epoch 53/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9245 - sparse_categorical_accuracy: 0.0483 - val_loss: 3.9414 - val_sparse_categorical_accuracy: 0.0377
# Epoch 54/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9216 - sparse_categorical_accuracy: 0.0373 - val_loss: 3.9405 - val_sparse_categorical_accuracy: 0.0340
# Epoch 55/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9218 - sparse_categorical_accuracy: 0.0424 - val_loss: 3.9407 - val_sparse_categorical_accuracy: 0.0340
# Epoch 56/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9194 - sparse_categorical_accuracy: 0.0408 - val_loss: 3.9398 - val_sparse_categorical_accuracy: 0.0340
# Epoch 57/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9198 - sparse_categorical_accuracy: 0.0487 - val_loss: 3.9401 - val_sparse_categorical_accuracy: 0.0491
# Epoch 58/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9253 - sparse_categorical_accuracy: 0.0428 - val_loss: 3.9389 - val_sparse_categorical_accuracy: 0.0415
# Epoch 59/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9212 - sparse_categorical_accuracy: 0.0428 - val_loss: 3.9391 - val_sparse_categorical_accuracy: 0.0528
# Epoch 60/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9214 - sparse_categorical_accuracy: 0.0465 - val_loss: 3.9393 - val_sparse_categorical_accuracy: 0.0264
# Epoch 61/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.9195 - sparse_categorical_accuracy: 0.0462 - val_loss: 3.9395 - val_sparse_categorical_accuracy: 0.0377
# Epoch 62/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9179 - sparse_categorical_accuracy: 0.0510 - val_loss: 3.9391 - val_sparse_categorical_accuracy: 0.0340
# Epoch 63/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9220 - sparse_categorical_accuracy: 0.0458 - val_loss: 3.9381 - val_sparse_categorical_accuracy: 0.0453
# Epoch 64/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9196 - sparse_categorical_accuracy: 0.0406 - val_loss: 3.9371 - val_sparse_categorical_accuracy: 0.0415
# Epoch 65/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.9188 - sparse_categorical_accuracy: 0.0488 - val_loss: 3.9390 - val_sparse_categorical_accuracy: 0.0377
# Epoch 66/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9244 - sparse_categorical_accuracy: 0.0403 - val_loss: 3.9400 - val_sparse_categorical_accuracy: 0.0340
# Epoch 67/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9163 - sparse_categorical_accuracy: 0.0441 - val_loss: 3.9373 - val_sparse_categorical_accuracy: 0.0528
# Epoch 68/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9127 - sparse_categorical_accuracy: 0.0510 - val_loss: 3.9362 - val_sparse_categorical_accuracy: 0.0453
# Epoch 69/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9174 - sparse_categorical_accuracy: 0.0451 - val_loss: 3.9379 - val_sparse_categorical_accuracy: 0.0302
# Epoch 70/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9140 - sparse_categorical_accuracy: 0.0451 - val_loss: 3.9368 - val_sparse_categorical_accuracy: 0.0377
# Epoch 71/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9154 - sparse_categorical_accuracy: 0.0427 - val_loss: 3.9381 - val_sparse_categorical_accuracy: 0.0415
# Epoch 72/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9145 - sparse_categorical_accuracy: 0.0421 - val_loss: 3.9364 - val_sparse_categorical_accuracy: 0.0302
# Epoch 73/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9190 - sparse_categorical_accuracy: 0.0447 - val_loss: 3.9360 - val_sparse_categorical_accuracy: 0.0415
# Epoch 74/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9159 - sparse_categorical_accuracy: 0.0442 - val_loss: 3.9361 - val_sparse_categorical_accuracy: 0.0340
# Epoch 75/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9110 - sparse_categorical_accuracy: 0.0442 - val_loss: 3.9358 - val_sparse_categorical_accuracy: 0.0415
# Epoch 76/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9112 - sparse_categorical_accuracy: 0.0495 - val_loss: 3.9362 - val_sparse_categorical_accuracy: 0.0642
# Epoch 77/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9104 - sparse_categorical_accuracy: 0.0524 - val_loss: 3.9360 - val_sparse_categorical_accuracy: 0.0377
# Epoch 78/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9110 - sparse_categorical_accuracy: 0.0511 - val_loss: 3.9360 - val_sparse_categorical_accuracy: 0.0377
# Epoch 79/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9113 - sparse_categorical_accuracy: 0.0466 - val_loss: 3.9351 - val_sparse_categorical_accuracy: 0.0377
# Epoch 80/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9106 - sparse_categorical_accuracy: 0.0501 - val_loss: 3.9355 - val_sparse_categorical_accuracy: 0.0415
# Epoch 81/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9166 - sparse_categorical_accuracy: 0.0506 - val_loss: 3.9347 - val_sparse_categorical_accuracy: 0.0453
# Epoch 82/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9093 - sparse_categorical_accuracy: 0.0455 - val_loss: 3.9345 - val_sparse_categorical_accuracy: 0.0528
# Epoch 83/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9105 - sparse_categorical_accuracy: 0.0556 - val_loss: 3.9355 - val_sparse_categorical_accuracy: 0.0415
# Epoch 84/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9092 - sparse_categorical_accuracy: 0.0538 - val_loss: 3.9347 - val_sparse_categorical_accuracy: 0.0340
# Epoch 85/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9126 - sparse_categorical_accuracy: 0.0506 - val_loss: 3.9358 - val_sparse_categorical_accuracy: 0.0415
# Epoch 86/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9120 - sparse_categorical_accuracy: 0.0532 - val_loss: 3.9339 - val_sparse_categorical_accuracy: 0.0415
# Epoch 87/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9086 - sparse_categorical_accuracy: 0.0505 - val_loss: 3.9333 - val_sparse_categorical_accuracy: 0.0415
# Epoch 88/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9073 - sparse_categorical_accuracy: 0.0573 - val_loss: 3.9325 - val_sparse_categorical_accuracy: 0.0528
# Epoch 89/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9082 - sparse_categorical_accuracy: 0.0507 - val_loss: 3.9334 - val_sparse_categorical_accuracy: 0.0604
# Epoch 90/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9085 - sparse_categorical_accuracy: 0.0461 - val_loss: 3.9337 - val_sparse_categorical_accuracy: 0.0491
# Epoch 91/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9060 - sparse_categorical_accuracy: 0.0476 - val_loss: 3.9331 - val_sparse_categorical_accuracy: 0.0264
# Epoch 92/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9075 - sparse_categorical_accuracy: 0.0463 - val_loss: 3.9323 - val_sparse_categorical_accuracy: 0.0415
# Epoch 93/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9043 - sparse_categorical_accuracy: 0.0546 - val_loss: 3.9317 - val_sparse_categorical_accuracy: 0.0377
# Epoch 94/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9063 - sparse_categorical_accuracy: 0.0466 - val_loss: 3.9324 - val_sparse_categorical_accuracy: 0.0415
# Epoch 95/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9095 - sparse_categorical_accuracy: 0.0585 - val_loss: 3.9338 - val_sparse_categorical_accuracy: 0.0528
# Epoch 96/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9091 - sparse_categorical_accuracy: 0.0516 - val_loss: 3.9335 - val_sparse_categorical_accuracy: 0.0453
# Epoch 97/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9094 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.9329 - val_sparse_categorical_accuracy: 0.0340
# Epoch 98/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9090 - sparse_categorical_accuracy: 0.0481 - val_loss: 3.9310 - val_sparse_categorical_accuracy: 0.0528
# Epoch 99/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9055 - sparse_categorical_accuracy: 0.0514 - val_loss: 3.9313 - val_sparse_categorical_accuracy: 0.0453
# Epoch 100/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9044 - sparse_categorical_accuracy: 0.0574 - val_loss: 3.9305 - val_sparse_categorical_accuracy: 0.0453
# Epoch 101/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9026 - sparse_categorical_accuracy: 0.0480 - val_loss: 3.9321 - val_sparse_categorical_accuracy: 0.0415
# Epoch 102/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8989 - sparse_categorical_accuracy: 0.0518 - val_loss: 3.9308 - val_sparse_categorical_accuracy: 0.0340
# Epoch 103/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9038 - sparse_categorical_accuracy: 0.0480 - val_loss: 3.9309 - val_sparse_categorical_accuracy: 0.0340
# Epoch 104/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9001 - sparse_categorical_accuracy: 0.0571 - val_loss: 3.9285 - val_sparse_categorical_accuracy: 0.0453
# Epoch 105/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9036 - sparse_categorical_accuracy: 0.0506 - val_loss: 3.9292 - val_sparse_categorical_accuracy: 0.0415
# Epoch 106/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9014 - sparse_categorical_accuracy: 0.0553 - val_loss: 3.9299 - val_sparse_categorical_accuracy: 0.0491
# Epoch 107/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8985 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.9296 - val_sparse_categorical_accuracy: 0.0415
# Epoch 108/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9078 - sparse_categorical_accuracy: 0.0508 - val_loss: 3.9294 - val_sparse_categorical_accuracy: 0.0528
# Epoch 109/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8989 - sparse_categorical_accuracy: 0.0578 - val_loss: 3.9309 - val_sparse_categorical_accuracy: 0.0491
# Epoch 110/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9019 - sparse_categorical_accuracy: 0.0515 - val_loss: 3.9299 - val_sparse_categorical_accuracy: 0.0528
# Epoch 111/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9041 - sparse_categorical_accuracy: 0.0522 - val_loss: 3.9300 - val_sparse_categorical_accuracy: 0.0415
# Epoch 112/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9024 - sparse_categorical_accuracy: 0.0552 - val_loss: 3.9272 - val_sparse_categorical_accuracy: 0.0491
# Epoch 113/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9024 - sparse_categorical_accuracy: 0.0511 - val_loss: 3.9291 - val_sparse_categorical_accuracy: 0.0491
# Epoch 114/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9007 - sparse_categorical_accuracy: 0.0536 - val_loss: 3.9298 - val_sparse_categorical_accuracy: 0.0340
# Epoch 115/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8994 - sparse_categorical_accuracy: 0.0546 - val_loss: 3.9283 - val_sparse_categorical_accuracy: 0.0415
# Epoch 116/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9025 - sparse_categorical_accuracy: 0.0487 - val_loss: 3.9292 - val_sparse_categorical_accuracy: 0.0453
# Epoch 117/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8996 - sparse_categorical_accuracy: 0.0459 - val_loss: 3.9281 - val_sparse_categorical_accuracy: 0.0491
# Epoch 118/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8947 - sparse_categorical_accuracy: 0.0578 - val_loss: 3.9287 - val_sparse_categorical_accuracy: 0.0491
# Epoch 119/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9015 - sparse_categorical_accuracy: 0.0591 - val_loss: 3.9280 - val_sparse_categorical_accuracy: 0.0453
# Epoch 120/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9019 - sparse_categorical_accuracy: 0.0533 - val_loss: 3.9274 - val_sparse_categorical_accuracy: 0.0491
# Epoch 121/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9050 - sparse_categorical_accuracy: 0.0528 - val_loss: 3.9297 - val_sparse_categorical_accuracy: 0.0453
# Epoch 122/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9025 - sparse_categorical_accuracy: 0.0548 - val_loss: 3.9261 - val_sparse_categorical_accuracy: 0.0528
# Epoch 123/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8997 - sparse_categorical_accuracy: 0.0505 - val_loss: 3.9275 - val_sparse_categorical_accuracy: 0.0453
# Epoch 124/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8982 - sparse_categorical_accuracy: 0.0555 - val_loss: 3.9266 - val_sparse_categorical_accuracy: 0.0453
# Epoch 125/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9026 - sparse_categorical_accuracy: 0.0531 - val_loss: 3.9265 - val_sparse_categorical_accuracy: 0.0528
# Epoch 126/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9002 - sparse_categorical_accuracy: 0.0529 - val_loss: 3.9264 - val_sparse_categorical_accuracy: 0.0453
# Epoch 127/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9014 - sparse_categorical_accuracy: 0.0546 - val_loss: 3.9253 - val_sparse_categorical_accuracy: 0.0453
# Epoch 128/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9006 - sparse_categorical_accuracy: 0.0537 - val_loss: 3.9299 - val_sparse_categorical_accuracy: 0.0453
# Epoch 129/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9004 - sparse_categorical_accuracy: 0.0535 - val_loss: 3.9246 - val_sparse_categorical_accuracy: 0.0528
# Epoch 130/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8961 - sparse_categorical_accuracy: 0.0548 - val_loss: 3.9254 - val_sparse_categorical_accuracy: 0.0528
# Epoch 131/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8965 - sparse_categorical_accuracy: 0.0581 - val_loss: 3.9265 - val_sparse_categorical_accuracy: 0.0491
# Epoch 132/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8993 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.9253 - val_sparse_categorical_accuracy: 0.0491
# Epoch 133/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8986 - sparse_categorical_accuracy: 0.0522 - val_loss: 3.9243 - val_sparse_categorical_accuracy: 0.0377
# Epoch 134/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8929 - sparse_categorical_accuracy: 0.0564 - val_loss: 3.9266 - val_sparse_categorical_accuracy: 0.0415
# Epoch 135/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8936 - sparse_categorical_accuracy: 0.0508 - val_loss: 3.9221 - val_sparse_categorical_accuracy: 0.0453
# Epoch 136/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9029 - sparse_categorical_accuracy: 0.0515 - val_loss: 3.9237 - val_sparse_categorical_accuracy: 0.0377
# Epoch 137/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8953 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.9243 - val_sparse_categorical_accuracy: 0.0491
# Epoch 138/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9032 - sparse_categorical_accuracy: 0.0596 - val_loss: 3.9236 - val_sparse_categorical_accuracy: 0.0453
# Epoch 139/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8984 - sparse_categorical_accuracy: 0.0554 - val_loss: 3.9252 - val_sparse_categorical_accuracy: 0.0377
# Epoch 140/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8985 - sparse_categorical_accuracy: 0.0560 - val_loss: 3.9241 - val_sparse_categorical_accuracy: 0.0377
# Epoch 141/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8898 - sparse_categorical_accuracy: 0.0553 - val_loss: 3.9233 - val_sparse_categorical_accuracy: 0.0566
# Epoch 142/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8932 - sparse_categorical_accuracy: 0.0558 - val_loss: 3.9238 - val_sparse_categorical_accuracy: 0.0453
# Epoch 143/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8972 - sparse_categorical_accuracy: 0.0600 - val_loss: 3.9220 - val_sparse_categorical_accuracy: 0.0566
# Epoch 144/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8958 - sparse_categorical_accuracy: 0.0576 - val_loss: 3.9223 - val_sparse_categorical_accuracy: 0.0491
# Epoch 145/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8929 - sparse_categorical_accuracy: 0.0617 - val_loss: 3.9250 - val_sparse_categorical_accuracy: 0.0491
# Epoch 146/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8968 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.9219 - val_sparse_categorical_accuracy: 0.0604
# Epoch 147/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8946 - sparse_categorical_accuracy: 0.0599 - val_loss: 3.9231 - val_sparse_categorical_accuracy: 0.0453
# Epoch 148/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8937 - sparse_categorical_accuracy: 0.0625 - val_loss: 3.9237 - val_sparse_categorical_accuracy: 0.0453
# Epoch 149/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8994 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.9223 - val_sparse_categorical_accuracy: 0.0491
# Epoch 150/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8910 - sparse_categorical_accuracy: 0.0623 - val_loss: 3.9203 - val_sparse_categorical_accuracy: 0.0415
# Epoch 151/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8928 - sparse_categorical_accuracy: 0.0531 - val_loss: 3.9222 - val_sparse_categorical_accuracy: 0.0415
# Epoch 152/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8967 - sparse_categorical_accuracy: 0.0556 - val_loss: 3.9198 - val_sparse_categorical_accuracy: 0.0491
# Epoch 153/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8922 - sparse_categorical_accuracy: 0.0562 - val_loss: 3.9213 - val_sparse_categorical_accuracy: 0.0453
# Epoch 154/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8949 - sparse_categorical_accuracy: 0.0560 - val_loss: 3.9203 - val_sparse_categorical_accuracy: 0.0566
# Epoch 155/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8931 - sparse_categorical_accuracy: 0.0584 - val_loss: 3.9219 - val_sparse_categorical_accuracy: 0.0528
# Epoch 156/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.8911 - sparse_categorical_accuracy: 0.0566 - val_loss: 3.9197 - val_sparse_categorical_accuracy: 0.0453
# Epoch 157/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8895 - sparse_categorical_accuracy: 0.0594 - val_loss: 3.9218 - val_sparse_categorical_accuracy: 0.0566
# Epoch 158/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8888 - sparse_categorical_accuracy: 0.0564 - val_loss: 3.9207 - val_sparse_categorical_accuracy: 0.0453
# Epoch 159/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8880 - sparse_categorical_accuracy: 0.0632 - val_loss: 3.9205 - val_sparse_categorical_accuracy: 0.0528
# Epoch 160/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8856 - sparse_categorical_accuracy: 0.0561 - val_loss: 3.9204 - val_sparse_categorical_accuracy: 0.0453
# Epoch 161/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8965 - sparse_categorical_accuracy: 0.0565 - val_loss: 3.9208 - val_sparse_categorical_accuracy: 0.0491
# Epoch 162/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.8900 - sparse_categorical_accuracy: 0.0552 - val_loss: 3.9207 - val_sparse_categorical_accuracy: 0.0528
# Epoch 163/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8796 - sparse_categorical_accuracy: 0.0582 - val_loss: 3.9213 - val_sparse_categorical_accuracy: 0.0566
# Epoch 164/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8912 - sparse_categorical_accuracy: 0.0568 - val_loss: 3.9204 - val_sparse_categorical_accuracy: 0.0528
# Epoch 165/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8957 - sparse_categorical_accuracy: 0.0562 - val_loss: 3.9203 - val_sparse_categorical_accuracy: 0.0453
# Epoch 166/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8883 - sparse_categorical_accuracy: 0.0549 - val_loss: 3.9190 - val_sparse_categorical_accuracy: 0.0566
# Epoch 167/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8935 - sparse_categorical_accuracy: 0.0608 - val_loss: 3.9181 - val_sparse_categorical_accuracy: 0.0415
# Epoch 168/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8894 - sparse_categorical_accuracy: 0.0538 - val_loss: 3.9226 - val_sparse_categorical_accuracy: 0.0566
# Epoch 169/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8839 - sparse_categorical_accuracy: 0.0582 - val_loss: 3.9193 - val_sparse_categorical_accuracy: 0.0566
# Epoch 170/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8890 - sparse_categorical_accuracy: 0.0582 - val_loss: 3.9181 - val_sparse_categorical_accuracy: 0.0566
# Epoch 171/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8944 - sparse_categorical_accuracy: 0.0597 - val_loss: 3.9183 - val_sparse_categorical_accuracy: 0.0491
# Epoch 172/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8911 - sparse_categorical_accuracy: 0.0586 - val_loss: 3.9183 - val_sparse_categorical_accuracy: 0.0491
# Epoch 173/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8980 - sparse_categorical_accuracy: 0.0611 - val_loss: 3.9177 - val_sparse_categorical_accuracy: 0.0528
# Epoch 174/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8926 - sparse_categorical_accuracy: 0.0663 - val_loss: 3.9172 - val_sparse_categorical_accuracy: 0.0453
# Epoch 175/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8804 - sparse_categorical_accuracy: 0.0665 - val_loss: 3.9171 - val_sparse_categorical_accuracy: 0.0415
# Epoch 176/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8909 - sparse_categorical_accuracy: 0.0585 - val_loss: 3.9172 - val_sparse_categorical_accuracy: 0.0453
# Epoch 177/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8926 - sparse_categorical_accuracy: 0.0564 - val_loss: 3.9173 - val_sparse_categorical_accuracy: 0.0491
# Epoch 178/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8925 - sparse_categorical_accuracy: 0.0551 - val_loss: 3.9187 - val_sparse_categorical_accuracy: 0.0566
# Epoch 179/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8941 - sparse_categorical_accuracy: 0.0601 - val_loss: 3.9176 - val_sparse_categorical_accuracy: 0.0491
# Epoch 180/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8899 - sparse_categorical_accuracy: 0.0534 - val_loss: 3.9173 - val_sparse_categorical_accuracy: 0.0528
# Epoch 181/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8840 - sparse_categorical_accuracy: 0.0547 - val_loss: 3.9168 - val_sparse_categorical_accuracy: 0.0604
# Epoch 182/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8845 - sparse_categorical_accuracy: 0.0617 - val_loss: 3.9168 - val_sparse_categorical_accuracy: 0.0566
# Epoch 183/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8855 - sparse_categorical_accuracy: 0.0642 - val_loss: 3.9184 - val_sparse_categorical_accuracy: 0.0491
# Epoch 184/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8827 - sparse_categorical_accuracy: 0.0572 - val_loss: 3.9166 - val_sparse_categorical_accuracy: 0.0528
# Epoch 185/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8868 - sparse_categorical_accuracy: 0.0630 - val_loss: 3.9174 - val_sparse_categorical_accuracy: 0.0491
# Epoch 186/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.8881 - sparse_categorical_accuracy: 0.0582 - val_loss: 3.9149 - val_sparse_categorical_accuracy: 0.0604
# Epoch 187/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8872 - sparse_categorical_accuracy: 0.0627 - val_loss: 3.9169 - val_sparse_categorical_accuracy: 0.0528
# Epoch 188/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8851 - sparse_categorical_accuracy: 0.0608 - val_loss: 3.9162 - val_sparse_categorical_accuracy: 0.0415
# Epoch 189/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8859 - sparse_categorical_accuracy: 0.0606 - val_loss: 3.9160 - val_sparse_categorical_accuracy: 0.0377
# Epoch 190/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8851 - sparse_categorical_accuracy: 0.0571 - val_loss: 3.9145 - val_sparse_categorical_accuracy: 0.0528
# Epoch 191/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8821 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.9150 - val_sparse_categorical_accuracy: 0.0566
# Epoch 192/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8912 - sparse_categorical_accuracy: 0.0554 - val_loss: 3.9147 - val_sparse_categorical_accuracy: 0.0453
# Epoch 193/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8862 - sparse_categorical_accuracy: 0.0580 - val_loss: 3.9163 - val_sparse_categorical_accuracy: 0.0566
# Epoch 194/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8895 - sparse_categorical_accuracy: 0.0587 - val_loss: 3.9153 - val_sparse_categorical_accuracy: 0.0415
# Epoch 195/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8836 - sparse_categorical_accuracy: 0.0643 - val_loss: 3.9147 - val_sparse_categorical_accuracy: 0.0566
# Epoch 196/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8872 - sparse_categorical_accuracy: 0.0612 - val_loss: 3.9160 - val_sparse_categorical_accuracy: 0.0566
# Epoch 197/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8882 - sparse_categorical_accuracy: 0.0597 - val_loss: 3.9154 - val_sparse_categorical_accuracy: 0.0566
# Epoch 198/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8778 - sparse_categorical_accuracy: 0.0625 - val_loss: 3.9134 - val_sparse_categorical_accuracy: 0.0528
# Epoch 199/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.8771 - sparse_categorical_accuracy: 0.0615 - val_loss: 3.9138 - val_sparse_categorical_accuracy: 0.0415
# Epoch 200/200
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8894 - sparse_categorical_accuracy: 0.0561 - val_loss: 3.9152 - val_sparse_categorical_accuracy: 0.0566

# %% [markdown]
# # Evaluación del modelo
#
# En este apartado se encuentra lo pedio en la tarea, además de algunas metricas adicionales.Empezaremos midiendo y comparando el de entrenamiento y validación.En el gráfico vemos que el error en entramiento baja, pero en validación esto no ocurre lo que indica sobre ajuste.

# %%
loss = hist.history["loss"]
val_loss = hist.history["val_loss"]

plt.plot(loss, label="loss")
plt.plot(val_loss, label="val_loss")
plt.title("Loss")
plt.legend()
plt.show()

# %% [markdown]
# El accuracy por otra parte no es estable en absoluto, en train el accuracy se mantiene estable pero no se puede decir lo mismo del conjunto de validación.Esto puede ser un indicativo de lo que ya sabiamos, el modelo esta practicamente adivinando la clase.

# %%
acc = hist.history["sparse_categorical_accuracy"]
val_acc = hist.history["val_sparse_categorical_accuracy"]

plt.plot(acc, label="acc")
plt.plot(val_acc, label="val_acc")
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# Los resutados numericos y la evalucación en test no son muy alentadores debido a que tenemos un error muy grande y accuracy muy baja, esto esta muy lejos de ser idal.La unica excepción es el error de entramiento que es razonablemente bajo pero su accuracy no ayuda mucho.

# %%
train_loss, train_acc = model.evaluate(X_train, y_train_num, verbose=0)
val_loss, val_acc = model.evaluate(X_val, y_val_num, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test_num, verbose=0)

print("TRAIN:")
print("Loss:", round(train_loss,3))
print("Accuracy:", round(train_acc,3))

print("\nVALIDATION:")
print("Loss:", round(val_loss,3))
print("Accuracy:", round(val_acc,3))

print("\nTEST:")
print("Loss:", round(test_loss,3))
print("Accuracy:", round(test_acc,3))
# Out:
# TRAIN:
# Loss: 3.884
# Accuracy: 0.06
#
# VALIDATION:
# Loss: 3.915
# Accuracy: 0.057
#
# TEST:
# Loss: 3.946
# Accuracy: 0.042

# %% [markdown]
# ## Matriz de confución.
#
# Vemos que a la hora de predecir el modelo no es muy bueno.

# %%
class_names = encoder.classes_


cm = confusion_matrix(y_test_num, np.argmax(model.predict(X_test), axis=1), normalize="true")


plt.figure(figsize=(20, 20))
sns.heatmap(cm,
            annot=True, cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names,
            cbar=True)

plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.title('Matriz de Confusión Tuneda')
plt.yticks(rotation=0)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %% [markdown]
# # Conclusión
#
# Este modelo simple no es suficiente para resolver este problema de clasificación debido a lo que hemos visto en las metricas anteriores, por lo tanto para la siguiente entrega debemos de crear una arquitectura más compleja.
