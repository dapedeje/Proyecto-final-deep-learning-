# %% [markdown]
# <font color="FF3B3B"><h1 align="left">Proyecto de aprendizaje profundo</h1></font>
# <font color="#6E6E6E"><h2 align="left">Modelo de red neuronal simple</h2></font>
#
# ##### David Alejandro Pedroza De Jesús
# ##### Joel Ezequiel Vicente Alonso
#
# Cargamos las librerias para la realización del proyecto

# %%
import sys
sys.path.append("../")
from modelos.RNNSimple import ModeloSimpleCLS
import numpy as np
import pandas as pd
import cv2
import kagglehub
import os
from shutil import move
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # Descarga, carga y limpieza de datos
#
# Aquí como siempre descargamos los datos y lo movemos a la carpeta de trabajo.

# %%
path = kagglehub.dataset_download("gpiosenka/cards-image-datasetclassification")
move(path,os.getcwd())
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/gpiosenka/cards-image-datasetclassification?dataset_version_number=2...
# 100%|██████████| 385M/385M [00:02<00:00, 195MB/s]
# Extracting files...
# '/content/2'

# %%
os.rename("2", "cards-image-datasetclassification")

# %%
datos = pd.read_csv(r"cards-image-datasetclassification/cards.csv")
datos.head()
# Out:
#    class index                   filepaths        labels card type data set
# 0            0  train/ace of clubs/001.jpg  ace of clubs       ace    train
# 1            0  train/ace of clubs/002.jpg  ace of clubs       ace    train
# 2            0  train/ace of clubs/003.jpg  ace of clubs       ace    train
# 3            0  train/ace of clubs/004.jpg  ace of clubs       ace    train
# 4            0  train/ace of clubs/005.jpg  ace of clubs       ace    train

# %% [markdown]
# Quitamos las rutas como hemos hecho siempre.

# %%
rutas_adaptadas = ["cards-image-datasetclassification/" +  ruta for ruta in datos["filepaths"]]
im_buenas = []
im_malas = []
for ru in rutas_adaptadas:
    im = cv2.imread(ru)
    if  im is not None:
        im_buenas.append(ru)
    else:
        im_malas.append(ru)
print(f"Lecturas correctas: {len(im_buenas)}")
print(f"Lecturas incorrectas: {len(im_malas)}")

df_limpio = datos[np.array(rutas_adaptadas) != np.array(im_malas)]
df_limpio["rutas_adap"] = im_buenas
# Out:
# Lecturas correctas: 8154
# Lecturas incorrectas: 1
# /tmp/ipython-input-267/4150467203.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["rutas_adap"] = im_buenas

# %% [markdown]
# Ahora creamos una función que normalice y cargue las imagenes, para ello crearemos una función que haga esa función.

# %%
def CargarImg(path, size):
    img = cv2.imread(path)
    img_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_resize = cv2.resize(img_RGB, size)
    return np.array(img_resize / 255.)

# %% [markdown]
# Cargamos los datos necesarios para el entrenamiento.

# %%
rutas_train = df_limpio[df_limpio["data set"] == "train"].rutas_adap
rutas_test = df_limpio[df_limpio["data set"] == "test"].rutas_adap
rutas_val = df_limpio[df_limpio["data set"] == "valid"].rutas_adap

X_train = np.array([CargarImg(path, (128, 128)) for path in rutas_train])
X_test = np.array([CargarImg(path, (128, 128)) for path in rutas_test])
X_val = np.array([CargarImg(path, (128, 128)) for path in rutas_val])

y_train = df_limpio[df_limpio["data set"] == "train"]["labels"]
y_test = df_limpio[df_limpio["data set"] == "test"]["labels"]
y_val = df_limpio[df_limpio["data set"] == "valid"]["labels"]

# %% [markdown]
# Por ultimo codificamos las salidas con laber encoder.

# %%
encoder = LabelEncoder()

y_train_num = encoder.fit_transform(y_train)
y_val_num   = encoder.transform(y_val)
y_test_num  = encoder.transform(y_test)

# %% [markdown]
# # Entrenamiento
#
# Ahora entraremos el modelo simple para ver que resultados tenemos.Primero cargaremos la arquitectura del modelo usando nuestra función de `modelos/RNNSimple.py`.

# %%
model = ModeloSimpleCLS((128, 128, 3), y_train.unique().shape[0])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 508032)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 53)             │    26,925,749 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,926,645 (102.72 MB)
#  Trainable params: 26,926,645 (102.72 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Ahora entrenamos nuestro modelo.

# %%
hist = model.fit(X_train, y_train_num,validation_data=(X_val, y_val_num), epochs=50)
# Out:
# Epoch 1/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - categorical_accuracy: 0.0245 - loss: 15.5311 - val_categorical_accuracy: 0.0491 - val_loss: 1.6443
# Epoch 2/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0177 - loss: 0.7287 - val_categorical_accuracy: 0.0264 - val_loss: 1.9112
# Epoch 3/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0213 - loss: 0.2475 - val_categorical_accuracy: 0.0340 - val_loss: 1.7155
# Epoch 4/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0178 - loss: 0.1300 - val_categorical_accuracy: 0.0151 - val_loss: 1.9369
# Epoch 5/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0205 - loss: 0.0577 - val_categorical_accuracy: 0.0226 - val_loss: 2.0098
# Epoch 6/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - categorical_accuracy: 0.0167 - loss: 0.0755 - val_categorical_accuracy: 0.0226 - val_loss: 2.4572
# Epoch 7/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0215 - loss: 0.0566 - val_categorical_accuracy: 0.0302 - val_loss: 2.1037
# Epoch 8/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0213 - loss: 0.0365 - val_categorical_accuracy: 0.0302 - val_loss: 1.8919
# Epoch 9/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - categorical_accuracy: 0.0211 - loss: 0.0392 - val_categorical_accuracy: 0.0302 - val_loss: 1.7571
# Epoch 10/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0202 - loss: 0.0314 - val_categorical_accuracy: 0.0302 - val_loss: 2.1652
# Epoch 11/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0213 - loss: 0.0206 - val_categorical_accuracy: 0.0415 - val_loss: 2.0855
# Epoch 12/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0224 - loss: 0.0436 - val_categorical_accuracy: 0.0226 - val_loss: 2.1937
# Epoch 13/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - categorical_accuracy: 0.0182 - loss: 0.0240 - val_categorical_accuracy: 0.0377 - val_loss: 2.1173
# Epoch 14/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0173 - loss: 0.0187 - val_categorical_accuracy: 0.0264 - val_loss: 2.3618
# Epoch 15/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - categorical_accuracy: 0.0222 - loss: 0.0331 - val_categorical_accuracy: 0.0340 - val_loss: 2.5154
# Epoch 16/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0171 - loss: 0.0375 - val_categorical_accuracy: 0.0377 - val_loss: 2.5059
# Epoch 17/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0170 - loss: 0.0686 - val_categorical_accuracy: 0.0264 - val_loss: 2.3967
# Epoch 18/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0206 - loss: 0.0455 - val_categorical_accuracy: 0.0340 - val_loss: 2.3299
# Epoch 19/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0188 - loss: 0.0225 - val_categorical_accuracy: 0.0189 - val_loss: 2.3170
# Epoch 20/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0196 - loss: 0.0188 - val_categorical_accuracy: 0.0264 - val_loss: 2.6276
# Epoch 21/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0154 - loss: 0.0090 - val_categorical_accuracy: 0.0302 - val_loss: 2.2792
# Epoch 22/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0210 - loss: 0.0066 - val_categorical_accuracy: 0.0226 - val_loss: 2.2549
# Epoch 23/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0173 - loss: 0.0084 - val_categorical_accuracy: 0.0226 - val_loss: 2.4174
# Epoch 24/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0176 - loss: 9.5861e-04 - val_categorical_accuracy: 0.0264 - val_loss: 2.3920
# Epoch 25/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0182 - loss: 0.0035 - val_categorical_accuracy: 0.0226 - val_loss: 2.3219
# Epoch 26/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0221 - loss: 0.0142 - val_categorical_accuracy: 0.0226 - val_loss: 2.5159
# Epoch 27/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0173 - loss: 0.0043 - val_categorical_accuracy: 0.0302 - val_loss: 2.4762
# Epoch 28/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - categorical_accuracy: 0.0207 - loss: 0.0100 - val_categorical_accuracy: 0.0302 - val_loss: 2.3716
# Epoch 29/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - categorical_accuracy: 0.0196 - loss: 0.0195 - val_categorical_accuracy: 0.0226 - val_loss: 2.5147
# Epoch 30/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - categorical_accuracy: 0.0162 - loss: 0.0054 - val_categorical_accuracy: 0.0189 - val_loss: 2.2970
# Epoch 31/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0186 - loss: 0.0056 - val_categorical_accuracy: 0.0453 - val_loss: 2.4668
# Epoch 32/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - categorical_accuracy: 0.0185 - loss: 0.0044 - val_categorical_accuracy: 0.0189 - val_loss: 2.4158
# Epoch 33/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - categorical_accuracy: 0.0176 - loss: 0.0114 - val_categorical_accuracy: 0.0340 - val_loss: 2.6789
# Epoch 34/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0179 - loss: 0.0304 - val_categorical_accuracy: 0.0302 - val_loss: 2.9845
# Epoch 35/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0153 - loss: 0.0406 - val_categorical_accuracy: 0.0377 - val_loss: 3.0351
# Epoch 36/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - categorical_accuracy: 0.0202 - loss: 0.0380 - val_categorical_accuracy: 0.0302 - val_loss: 3.0121
# Epoch 37/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - categorical_accuracy: 0.0189 - loss: 0.0418 - val_categorical_accuracy: 0.0264 - val_loss: 3.1192
# Epoch 38/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - categorical_accuracy: 0.0187 - loss: 0.0086 - val_categorical_accuracy: 0.0377 - val_loss: 2.9036
# Epoch 39/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.0219 - loss: 0.0075 - val_categorical_accuracy: 0.0226 - val_loss: 2.9320
# Epoch 40/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0183 - loss: 0.0153 - val_categorical_accuracy: 0.0226 - val_loss: 2.9191
# Epoch 41/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0177 - loss: 0.0017 - val_categorical_accuracy: 0.0377 - val_loss: 2.9406
# Epoch 42/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0187 - loss: 0.0097 - val_categorical_accuracy: 0.0226 - val_loss: 2.8042
# Epoch 43/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0192 - loss: 0.0067 - val_categorical_accuracy: 0.0302 - val_loss: 2.7755
# Epoch 44/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0161 - loss: 0.0035 - val_categorical_accuracy: 0.0264 - val_loss: 2.8920
# Epoch 45/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - categorical_accuracy: 0.0232 - loss: 0.0152 - val_categorical_accuracy: 0.0302 - val_loss: 2.9138
# Epoch 46/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0205 - loss: 0.0041 - val_categorical_accuracy: 0.0302 - val_loss: 2.8388
# Epoch 47/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0186 - loss: 0.0018 - val_categorical_accuracy: 0.0264 - val_loss: 2.7597
# Epoch 48/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0197 - loss: 0.0033 - val_categorical_accuracy: 0.0264 - val_loss: 2.8871
# Epoch 49/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - categorical_accuracy: 0.0188 - loss: 0.0049 - val_categorical_accuracy: 0.0189 - val_loss: 2.8054
# Epoch 50/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.0156 - loss: 0.0070 - val_categorical_accuracy: 0.0377 - val_loss: 3.3046

# %% [markdown]
# # Evaluación del modelo
#
# En este apartado se encuentra lo pedio en la tarea, además de algunas metricas adicionales.Empezaremos midiendo y comparando el de entrenamiento y validación.En el gráfico vemos que el error en entramiento baja, pero en validación esto no ocurre lo que indica sobre ajuste.

# %%
loss = hist.history["loss"]
val_loss = hist.history["val_loss"]

plt.plot(loss, label="loss")
plt.plot(val_loss, label="val_loss")
plt.title("Loss")
plt.legend()
plt.show()

# %% [markdown]
# El accuracy por otra parte no es estable en absoluto, en train el accuracy se mantiene estable pero no se puede decir lo mismo del conjunto de validación.Esto puede ser un indicativo de lo que ya sabiamos, el modelo esta practicamente adivinando la clase.

# %%
acc = hist.history["categorical_accuracy"]
val_acc = hist.history["val_categorical_accuracy"]

plt.plot(acc, label="acc")
plt.plot(val_acc, label="val_acc")
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# Los resutados numericos y la evalucación en test no son muy alentadores debido a que tenemos un error muy grande y accuracy muy baja, esto esta muy lejos de ser idal.La unica excepción es el error de entramiento que es razonablemente bajo pero su accuracy no ayuda mucho.

# %%
train_loss, train_acc = model.evaluate(X_train, y_train_num, verbose=0)
val_loss, val_acc = model.evaluate(X_val, y_val_num, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test_num, verbose=0)

print("TRAIN:")
print("Loss:", round(train_loss,3))
print("Accuracy:", round(train_acc,3))

print("\nVALIDATION:")
print("Loss:", round(val_loss,3))
print("Accuracy:", round(val_acc,3))

print("\nTEST:")
print("Loss:", round(test_loss,3))
print("Accuracy:", round(test_acc,3))
# Out:
# TRAIN:
# Loss: 0.016
# Accuracy: 0.013
#
# VALIDATION:
# Loss: 3.305
# Accuracy: 0.038
#
# TEST:
# Loss: 3.393
# Accuracy: 0.026

# %% [markdown]
# ## Matriz de confución.
#
# Vemos que a la hora de predecir el modelo no es muy bueno.

# %%
class_names = encoder.classes_


cm = confusion_matrix(y_test_num, np.argmax(model.predict(X_test), axis=1), normalize="true")


plt.figure(figsize=(20, 20))
sns.heatmap(cm,
            annot=True, cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names,
            cbar=True)

plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.title('Matriz de Confusión Tuneda')
plt.yticks(rotation=0)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %% [markdown]
# # Conclusión
#
# Este modelo simple no es suficiente para resolver este problema de clasificación debido a lo que hemos visto en las metricas anteriores, por lo tanto para la siguiente entrega debemos de crear una arquitectura más compleja.
