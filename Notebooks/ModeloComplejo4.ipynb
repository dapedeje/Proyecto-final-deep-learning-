# %% [markdown]
# <font color="FF3B3B"><h1 align="left">Proyecto de aprendizaje profundo</h1></font>
# <font color="#6E6E6E"><h2 align="left">Modelo complejo CNN Nº 4</h2></font>
#
# ##### David Alejandro Pedroza De Jesús
# ##### Joel Ezequiel Vicente Alonso
#
# Cargamos las librerias para la realización del proyecto

# %%
import sys
sys.path.append("../")
from modelos.CNNComplejo4 import ModeloComplejo
import numpy as np
import pandas as pd
import cv2
import kagglehub
import os
from shutil import move
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # Resumen
#
# Debido a que el modelo 2 no aprende, lo que puede deverce a que esta muy regularizado, por lo que haremos un modelo 3 en el cual mantedremos el numero de capas pero quitaremos algo de la regularización.

# %% [markdown]
# # Cargar las imagenes
#
# Hararemos el procesado que hemos hecho antes, tanto con las etiquetas e imagenes.

# %%
path = kagglehub.dataset_download("gpiosenka/cards-image-datasetclassification")
print(path)
# Out:
# Using Colab cache for faster access to the 'cards-image-datasetclassification' dataset.
# /kaggle/input/cards-image-datasetclassification

# %%
move(path,os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipykernel_10337/3271023425.py in <cell line: 0>()
# ----> 1 move(path,os.getcwd())
#
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     843
#     844         if os.path.exists(real_dst):
# --> 845             raise Error("Destination path '%s' already exists" % real_dst)
#     846     try:
#     847         os.rename(src, real_dst)
#
# Error: Destination path '/content/cards-image-datasetclassification' already exists

# %%
os.rename("2","cards-image-datasetclassification")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10337/2146948587.py in <cell line: 0>()
# ----> 1 os.rename("2","cards-image-datasetclassification")
#
# FileNotFoundError: [Errno 2] No such file or directory: '2' -> 'cards-image-datasetclassification'

# %%
datos = pd.read_csv(r"cards-image-datasetclassification/cards.csv")
datos.head()
# Out:
#    class index                   filepaths        labels card type data set
# 0            0  train/ace of clubs/001.jpg  ace of clubs       ace    train
# 1            0  train/ace of clubs/002.jpg  ace of clubs       ace    train
# 2            0  train/ace of clubs/003.jpg  ace of clubs       ace    train
# 3            0  train/ace of clubs/004.jpg  ace of clubs       ace    train
# 4            0  train/ace of clubs/005.jpg  ace of clubs       ace    train

# %% [markdown]
# Arreglamos las rutas.

# %%
rutas_adaptadas = ["cards-image-datasetclassification/" +  ruta for ruta in datos["filepaths"]]
im_buenas = []
im_malas = []
for ru in rutas_adaptadas:
    im = cv2.imread(ru)
    if  im is not None:
        im_buenas.append(ru)
    else:
        im_malas.append(ru)
#print(f"Lecturas correctas: {len(im_buenas)}")
#print(f"Lecturas incorrectas: {len(im_malas)}")

df_limpio = datos[np.array(rutas_adaptadas) != np.array(im_malas)]
df_limpio["rutas_adap"] = im_buenas
# Out:
# /tmp/ipykernel_10337/1813950221.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["rutas_adap"] = im_buenas

# %% [markdown]
# Ahora cargamos las imagenes, añadiremos un procesado más, debido a que no necesitamos toda la carta para realizar la predicción.

# %%
def CargarImg(path, size):
    img = cv2.imread(path)
    img_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)[0:75,0:75]#De con esto ya tenemos toda la información
    img_resize = cv2.resize(img_RGB, size)
    return np.array(img_resize / 255.)

# %%
rutas_train = df_limpio[df_limpio["data set"] == "train"].rutas_adap
rutas_test = df_limpio[df_limpio["data set"] == "test"].rutas_adap
rutas_val = df_limpio[df_limpio["data set"] == "valid"].rutas_adap

X_train = np.array([CargarImg(path, (75, 75)) for path in rutas_train])
X_test = np.array([CargarImg(path, (75, 75)) for path in rutas_test])
X_val = np.array([CargarImg(path, (75, 75)) for path in rutas_val])

y_train = df_limpio[df_limpio["data set"] == "train"]["labels"]
y_test = df_limpio[df_limpio["data set"] == "test"]["labels"]
y_val = df_limpio[df_limpio["data set"] == "valid"]["labels"]

# %% [markdown]
# Y codificamos los labels con `LabelEncoder()`

# %%
encoder = LabelEncoder()

y_train_num = encoder.fit_transform(y_train)
y_val_num   = encoder.transform(y_val)
y_test_num  = encoder.transform(y_test)

# %% [markdown]
# # Arquitectura de la red
#
# En este apartado iremos probando la arquitectura, en este hemos añadido capas dos capas dense y dos capas convolucionales.

# %%
input_shape = X_train[0].shape
num_clases = np.unique(y_train_num).shape[0]
model = ModeloComplejo(input_shape, num_clases)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 75, 75, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 37, 37, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_7 (ReLU)                  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 18, 18, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 18, 18, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 10368)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │     2,654,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 53)             │        13,621 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,761,333 (10.53 MB)
#  Trainable params: 2,761,333 (10.53 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# También aquí hacemos un plot de la arquitectura del modelo.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# # Entrenamiento
#
# En este apartado realizaremos el entrenamiento.

# %%
hist = model.fit(X_train, y_train_num,validation_data=(X_val, y_val_num), epochs=50)
# Out:
# Epoch 1/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 3.6725 - sparse_categorical_accuracy: 0.0622 - val_loss: 2.2009 - val_sparse_categorical_accuracy: 0.3623
# Epoch 2/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.0431 - sparse_categorical_accuracy: 0.4370 - val_loss: 0.9998 - val_sparse_categorical_accuracy: 0.6981
# Epoch 3/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 1.0691 - sparse_categorical_accuracy: 0.7062 - val_loss: 0.6900 - val_sparse_categorical_accuracy: 0.7887
# Epoch 4/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.5773 - sparse_categorical_accuracy: 0.8439 - val_loss: 0.7823 - val_sparse_categorical_accuracy: 0.8038
# Epoch 5/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.3379 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.8266 - val_sparse_categorical_accuracy: 0.8491
# Epoch 6/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2475 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.8067 - val_sparse_categorical_accuracy: 0.8377
# Epoch 7/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1685 - sparse_categorical_accuracy: 0.9597 - val_loss: 0.8793 - val_sparse_categorical_accuracy: 0.8566
# Epoch 8/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1371 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.8340 - val_sparse_categorical_accuracy: 0.8491
# Epoch 9/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1395 - sparse_categorical_accuracy: 0.9627 - val_loss: 1.0538 - val_sparse_categorical_accuracy: 0.8226
# Epoch 10/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1134 - sparse_categorical_accuracy: 0.9734 - val_loss: 0.9167 - val_sparse_categorical_accuracy: 0.8377
# Epoch 11/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1341 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.9103 - val_sparse_categorical_accuracy: 0.8642
# Epoch 12/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0905 - sparse_categorical_accuracy: 0.9760 - val_loss: 1.1930 - val_sparse_categorical_accuracy: 0.8151
# Epoch 13/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0839 - sparse_categorical_accuracy: 0.9783 - val_loss: 1.0046 - val_sparse_categorical_accuracy: 0.8302
# Epoch 14/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9829 - val_loss: 1.0651 - val_sparse_categorical_accuracy: 0.8340
# Epoch 15/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0498 - sparse_categorical_accuracy: 0.9877 - val_loss: 1.2534 - val_sparse_categorical_accuracy: 0.8189
# Epoch 16/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0560 - sparse_categorical_accuracy: 0.9861 - val_loss: 1.3248 - val_sparse_categorical_accuracy: 0.8415
# Epoch 17/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0997 - sparse_categorical_accuracy: 0.9743 - val_loss: 1.1858 - val_sparse_categorical_accuracy: 0.8226
# Epoch 18/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0711 - sparse_categorical_accuracy: 0.9808 - val_loss: 1.1564 - val_sparse_categorical_accuracy: 0.8340
# Epoch 19/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9862 - val_loss: 1.4253 - val_sparse_categorical_accuracy: 0.8377
# Epoch 20/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0624 - sparse_categorical_accuracy: 0.9793 - val_loss: 1.2645 - val_sparse_categorical_accuracy: 0.8491
# Epoch 21/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0486 - sparse_categorical_accuracy: 0.9876 - val_loss: 1.4769 - val_sparse_categorical_accuracy: 0.8226
# Epoch 22/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9884 - val_loss: 1.3471 - val_sparse_categorical_accuracy: 0.8113
# Epoch 23/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0623 - sparse_categorical_accuracy: 0.9841 - val_loss: 1.3553 - val_sparse_categorical_accuracy: 0.8377
# Epoch 24/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0259 - sparse_categorical_accuracy: 0.9929 - val_loss: 1.0819 - val_sparse_categorical_accuracy: 0.8453
# Epoch 25/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9934 - val_loss: 1.1572 - val_sparse_categorical_accuracy: 0.8491
# Epoch 26/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0252 - sparse_categorical_accuracy: 0.9924 - val_loss: 1.0812 - val_sparse_categorical_accuracy: 0.8792
# Epoch 27/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9952 - val_loss: 1.1345 - val_sparse_categorical_accuracy: 0.8528
# Epoch 28/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9945 - val_loss: 1.1684 - val_sparse_categorical_accuracy: 0.8264
# Epoch 29/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0185 - sparse_categorical_accuracy: 0.9954 - val_loss: 1.2295 - val_sparse_categorical_accuracy: 0.8415
# Epoch 30/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0174 - sparse_categorical_accuracy: 0.9954 - val_loss: 1.0820 - val_sparse_categorical_accuracy: 0.8642
# Epoch 31/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0567 - sparse_categorical_accuracy: 0.9839 - val_loss: 1.3068 - val_sparse_categorical_accuracy: 0.7962
# Epoch 32/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1915 - sparse_categorical_accuracy: 0.9532 - val_loss: 1.3163 - val_sparse_categorical_accuracy: 0.7962
# Epoch 33/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0614 - sparse_categorical_accuracy: 0.9835 - val_loss: 1.1459 - val_sparse_categorical_accuracy: 0.8113
# Epoch 34/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0316 - sparse_categorical_accuracy: 0.9919 - val_loss: 1.1547 - val_sparse_categorical_accuracy: 0.8415
# Epoch 35/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0268 - sparse_categorical_accuracy: 0.9935 - val_loss: 1.3037 - val_sparse_categorical_accuracy: 0.8528
# Epoch 36/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9952 - val_loss: 1.2786 - val_sparse_categorical_accuracy: 0.8792
# Epoch 37/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9970 - val_loss: 1.2196 - val_sparse_categorical_accuracy: 0.8679
# Epoch 38/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9962 - val_loss: 1.1258 - val_sparse_categorical_accuracy: 0.8755
# Epoch 39/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9955 - val_loss: 1.1993 - val_sparse_categorical_accuracy: 0.8755
# Epoch 40/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9971 - val_loss: 1.2222 - val_sparse_categorical_accuracy: 0.8755
# Epoch 41/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9970 - val_loss: 1.4341 - val_sparse_categorical_accuracy: 0.8377
# Epoch 42/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9941 - val_loss: 1.9624 - val_sparse_categorical_accuracy: 0.7509
# Epoch 43/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1498 - sparse_categorical_accuracy: 0.9674 - val_loss: 1.7379 - val_sparse_categorical_accuracy: 0.8038
# Epoch 44/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0609 - sparse_categorical_accuracy: 0.9860 - val_loss: 1.3406 - val_sparse_categorical_accuracy: 0.8491
# Epoch 45/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0287 - sparse_categorical_accuracy: 0.9905 - val_loss: 1.4235 - val_sparse_categorical_accuracy: 0.8453
# Epoch 46/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0273 - sparse_categorical_accuracy: 0.9933 - val_loss: 1.3120 - val_sparse_categorical_accuracy: 0.8415
# Epoch 47/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0169 - sparse_categorical_accuracy: 0.9953 - val_loss: 1.4426 - val_sparse_categorical_accuracy: 0.8453
# Epoch 48/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9962 - val_loss: 1.4255 - val_sparse_categorical_accuracy: 0.8302
# Epoch 49/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0231 - sparse_categorical_accuracy: 0.9945 - val_loss: 1.6776 - val_sparse_categorical_accuracy: 0.8491
# Epoch 50/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9904 - val_loss: 1.4766 - val_sparse_categorical_accuracy: 0.8113

# %% [markdown]
# # Evaluación del modelo
#
# En este caso podemos ver que el modelo mejora con respecto al anterior, pero vemos que esta algo sobre ajustado, por lo que el modelo si que requiere aplicar un punto medio de regularización.

# %%
loss = hist.history["loss"]
val_loss = hist.history["val_loss"]

plt.plot(loss, label="loss")
plt.plot(val_loss, label="val_loss")
plt.title("Loss")
plt.legend()
plt.show()

# %% [markdown]
# El modelo evidentemente esta aprendiendo y funciona relativamente bien en validación, pero como hemos dicho antes tenemos sobreajuste, si solucionamos esto el modelo puede ser mucho mejor.

# %%
acc = hist.history["sparse_categorical_accuracy"]
val_acc = hist.history["val_sparse_categorical_accuracy"]

plt.plot(acc, label="acc")
plt.plot(val_acc, label="val_acc")
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# El modelo funciona peor en el conjunto de test, lo que es esperable, debido a que hemos dicho antes, por el sobre ajuste.

# %%
train_loss, train_acc = model.evaluate(X_train, y_train_num, verbose=0)
val_loss, val_acc = model.evaluate(X_val, y_val_num, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test_num, verbose=0)

print("TRAIN:")
print("Loss:", round(train_loss,3))
print("Accuracy:", round(train_acc,3))

print("\nVALIDATION:")
print("Loss:", round(val_loss,3))
print("Accuracy:", round(val_acc,3))

print("\nTEST:")
print("Loss:", round(test_loss,3))
print("Accuracy:", round(test_acc,3))
# Out:
# TRAIN:
# Loss: 0.043
# Accuracy: 0.989
#
# VALIDATION:
# Loss: 1.477
# Accuracy: 0.811
#
# TEST:
# Loss: 1.603
# Accuracy: 0.762

# %% [markdown]
# # Matriz de confución
#
# Si miramos la matriz de confusión, el modelo funciona razonablemente bien, recordemos que es para detección de cartas; pero aun hay mucho margen de mejora.

# %%
class_names = encoder.classes_

cm = confusion_matrix(y_test_num, np.argmax(model.predict(X_test), axis=1), normalize="true")

plt.figure(figsize=(20, 20))
sns.heatmap(cm,
            annot=True, cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names,
            cbar=True)

plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.title('Matriz de Confusión')
plt.yticks(rotation=0)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step

# %% [markdown]
# # Conclusión
#
# El modelo complejo 3 parece ser bueno, pero aun tenemos margen de mejora.
