# %% [markdown]
# <font color="FF3B3B"><h1 align="left">Proyecto de aprendizaje profundo</h1></font>
# <font color="#6E6E6E"><h2 align="left">Modelo complejo CNN Nº 8</h2></font>
#
# ##### David Alejandro Pedroza De Jesús
# ##### Joel Ezequiel Vicente Alonso
#
# Cargamos las librerias para la realización del proyecto

# %%
import sys
sys.path.append("../")
from modelos.CNNComplejo9 import ModeloComplejo
import numpy as np
import pandas as pd
import cv2
import kagglehub
import os
from shutil import move
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns
from tensorflow.keras.utils import plot_model

# %%
path = kagglehub.dataset_download("gpiosenka/cards-image-datasetclassification")
print(path)
# Out:
# Using Colab cache for faster access to the 'cards-image-datasetclassification' dataset.
# /kaggle/input/cards-image-datasetclassification

# %%
move(path,os.getcwd())

# %%
os.rename("2","cards-image-datasetclassification")

# %% [markdown]
# # Resumen
#
# En este caso hemos decidico probar aplicando un upsampling, el cual es una capa que es contraria a la convolución, para ver si da buenos resultados.

# %% [markdown]
# # Cargar las imagenes
#
# Hararemos el procesado que hemos hecho antes, tanto con las etiquetas e imagenes.

# %%
datos = pd.read_csv(r"cards-image-datasetclassification/cards.csv")
datos.head()
# Out:
#    class index                   filepaths        labels card type data set
# 0            0  train/ace of clubs/001.jpg  ace of clubs       ace    train
# 1            0  train/ace of clubs/002.jpg  ace of clubs       ace    train
# 2            0  train/ace of clubs/003.jpg  ace of clubs       ace    train
# 3            0  train/ace of clubs/004.jpg  ace of clubs       ace    train
# 4            0  train/ace of clubs/005.jpg  ace of clubs       ace    train

# %% [markdown]
# Arreglamos las rutas.

# %%
rutas_adaptadas = ["cards-image-datasetclassification/" +  ruta for ruta in datos["filepaths"]]
im_buenas = []
im_malas = []
for ru in rutas_adaptadas:
    im = cv2.imread(ru)
    if  im is not None:
        im_buenas.append(ru)
    else:
        im_malas.append(ru)
#print(f"Lecturas correctas: {len(im_buenas)}")
#print(f"Lecturas incorrectas: {len(im_malas)}")

df_limpio = datos[np.array(rutas_adaptadas) != np.array(im_malas)]
df_limpio["rutas_adap"] = im_buenas
# Out:
# /tmp/ipykernel_697/1813950221.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["rutas_adap"] = im_buenas

# %% [markdown]
# Ahora cargamos las imagenes, añadiremos un procesado más, debido a que no necesitamos toda la carta para realizar la predicción.

# %%
def CargarImg(path, size):
    img = cv2.imread(path)
    img_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)[0:75,0:75]#De con esto ya tenemos toda la información
    img_resize = cv2.resize(img_RGB, size)
    return np.array(img_resize / 255.)

# %%
rutas_train = df_limpio[df_limpio["data set"] == "train"].rutas_adap
rutas_test = df_limpio[df_limpio["data set"] == "test"].rutas_adap
rutas_val = df_limpio[df_limpio["data set"] == "valid"].rutas_adap

X_train = np.array([CargarImg(path, (75, 75)) for path in rutas_train])
X_test = np.array([CargarImg(path, (75, 75)) for path in rutas_test])
X_val = np.array([CargarImg(path, (75, 75)) for path in rutas_val])

y_train = df_limpio[df_limpio["data set"] == "train"]["labels"]
y_test = df_limpio[df_limpio["data set"] == "test"]["labels"]
y_val = df_limpio[df_limpio["data set"] == "valid"]["labels"]

# %% [markdown]
# Y codificamos los labels con `LabelEncoder()`

# %%
encoder = LabelEncoder()

y_train_num = encoder.fit_transform(y_train)
y_val_num   = encoder.transform(y_val)
y_test_num  = encoder.transform(y_test)

# %% [markdown]
# # Arquitectura de la red
#
# En este apartado iremos probando la arquitectura, en este hemos añadido capas dos capas dense y dos capas convolucionales.

# %%
input_shape = X_train[0].shape
num_clases = np.unique(y_train_num).shape[0]
model = ModeloComplejo(input_shape, num_clases)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 75, 75, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 75, 75, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 75, 75, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 75, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 37, 37, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 74, 74, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 74, 74, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 74, 74, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 74, 74, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 37, 37, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 18, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 18, 18, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 18, 18, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 18, 18, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 9, 9, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 9, 9, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 5184)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       331,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        16,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 53)             │        13,621 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 395,765 (1.51 MB)
#  Trainable params: 395,349 (1.51 MB)
#  Non-trainable params: 416 (1.62 KB)

# %% [markdown]
# También aquí hacemos un plot de la arquitectura del modelo.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# # Entrenamiento
#
# En este apartado realizaremos el entrenamiento.

# %%
hist = model.fit(X_train, y_train_num,validation_data=(X_val, y_val_num), epochs=100)
# Out:
# Epoch 1/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 28s 57ms/step - loss: 3.6790 - sparse_categorical_accuracy: 0.0582 - val_loss: 3.8260 - val_sparse_categorical_accuracy: 0.0377
# Epoch 2/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 3.2182 - sparse_categorical_accuracy: 0.1026 - val_loss: 2.8604 - val_sparse_categorical_accuracy: 0.1396
# Epoch 3/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 3.0252 - sparse_categorical_accuracy: 0.1434 - val_loss: 2.5689 - val_sparse_categorical_accuracy: 0.1925
# Epoch 4/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.8339 - sparse_categorical_accuracy: 0.1790 - val_loss: 2.2271 - val_sparse_categorical_accuracy: 0.2981
# Epoch 5/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 2.6196 - sparse_categorical_accuracy: 0.2344 - val_loss: 2.0789 - val_sparse_categorical_accuracy: 0.4038
# Epoch 6/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.4233 - sparse_categorical_accuracy: 0.2932 - val_loss: 1.6157 - val_sparse_categorical_accuracy: 0.5208
# Epoch 7/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.2458 - sparse_categorical_accuracy: 0.3363 - val_loss: 1.5549 - val_sparse_categorical_accuracy: 0.5774
# Epoch 8/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.0485 - sparse_categorical_accuracy: 0.3980 - val_loss: 1.1971 - val_sparse_categorical_accuracy: 0.6642
# Epoch 9/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.8859 - sparse_categorical_accuracy: 0.4441 - val_loss: 1.1022 - val_sparse_categorical_accuracy: 0.6755
# Epoch 10/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7884 - sparse_categorical_accuracy: 0.4677 - val_loss: 0.9759 - val_sparse_categorical_accuracy: 0.6868
# Epoch 11/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6582 - sparse_categorical_accuracy: 0.5047 - val_loss: 0.8664 - val_sparse_categorical_accuracy: 0.7849
# Epoch 12/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6053 - sparse_categorical_accuracy: 0.5269 - val_loss: 0.7768 - val_sparse_categorical_accuracy: 0.8226
# Epoch 13/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5374 - sparse_categorical_accuracy: 0.5393 - val_loss: 0.6137 - val_sparse_categorical_accuracy: 0.8491
# Epoch 14/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4693 - sparse_categorical_accuracy: 0.5602 - val_loss: 0.7668 - val_sparse_categorical_accuracy: 0.8038
# Epoch 15/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1.4228 - sparse_categorical_accuracy: 0.5748 - val_loss: 0.7552 - val_sparse_categorical_accuracy: 0.8038
# Epoch 16/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.3741 - sparse_categorical_accuracy: 0.5830 - val_loss: 0.6168 - val_sparse_categorical_accuracy: 0.8226
# Epoch 17/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3109 - sparse_categorical_accuracy: 0.6114 - val_loss: 0.6019 - val_sparse_categorical_accuracy: 0.8340
# Epoch 18/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.2626 - sparse_categorical_accuracy: 0.6127 - val_loss: 0.6979 - val_sparse_categorical_accuracy: 0.8302
# Epoch 19/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.2379 - sparse_categorical_accuracy: 0.6243 - val_loss: 0.5184 - val_sparse_categorical_accuracy: 0.8642
# Epoch 20/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.1850 - sparse_categorical_accuracy: 0.6381 - val_loss: 0.5031 - val_sparse_categorical_accuracy: 0.8755
# Epoch 21/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1573 - sparse_categorical_accuracy: 0.6510 - val_loss: 0.4971 - val_sparse_categorical_accuracy: 0.8792
# Epoch 22/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1.1535 - sparse_categorical_accuracy: 0.6527 - val_loss: 0.5037 - val_sparse_categorical_accuracy: 0.8566
# Epoch 23/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.1021 - sparse_categorical_accuracy: 0.6666 - val_loss: 0.7899 - val_sparse_categorical_accuracy: 0.7660
# Epoch 24/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0832 - sparse_categorical_accuracy: 0.6729 - val_loss: 0.4508 - val_sparse_categorical_accuracy: 0.8943
# Epoch 25/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.0702 - sparse_categorical_accuracy: 0.6768 - val_loss: 0.4034 - val_sparse_categorical_accuracy: 0.8868
# Epoch 26/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.0435 - sparse_categorical_accuracy: 0.6785 - val_loss: 0.3865 - val_sparse_categorical_accuracy: 0.8943
# Epoch 27/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.0222 - sparse_categorical_accuracy: 0.6914 - val_loss: 0.3543 - val_sparse_categorical_accuracy: 0.9132
# Epoch 28/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.9829 - sparse_categorical_accuracy: 0.6937 - val_loss: 0.3586 - val_sparse_categorical_accuracy: 0.8906
# Epoch 29/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9828 - sparse_categorical_accuracy: 0.6977 - val_loss: 0.4489 - val_sparse_categorical_accuracy: 0.8981
# Epoch 30/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.9470 - sparse_categorical_accuracy: 0.7108 - val_loss: 0.4502 - val_sparse_categorical_accuracy: 0.8830
# Epoch 31/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.9291 - sparse_categorical_accuracy: 0.7146 - val_loss: 0.4371 - val_sparse_categorical_accuracy: 0.8830
# Epoch 32/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9409 - sparse_categorical_accuracy: 0.7112 - val_loss: 0.5555 - val_sparse_categorical_accuracy: 0.8642
# Epoch 33/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9276 - sparse_categorical_accuracy: 0.7125 - val_loss: 0.3569 - val_sparse_categorical_accuracy: 0.8943
# Epoch 34/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.9165 - sparse_categorical_accuracy: 0.7181 - val_loss: 0.4069 - val_sparse_categorical_accuracy: 0.8906
# Epoch 35/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8899 - sparse_categorical_accuracy: 0.7277 - val_loss: 0.3746 - val_sparse_categorical_accuracy: 0.8830
# Epoch 36/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8809 - sparse_categorical_accuracy: 0.7273 - val_loss: 0.2965 - val_sparse_categorical_accuracy: 0.9208
# Epoch 37/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8410 - sparse_categorical_accuracy: 0.7390 - val_loss: 0.3379 - val_sparse_categorical_accuracy: 0.8943
# Epoch 38/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8468 - sparse_categorical_accuracy: 0.7409 - val_loss: 0.4182 - val_sparse_categorical_accuracy: 0.8830
# Epoch 39/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8516 - sparse_categorical_accuracy: 0.7361 - val_loss: 0.2867 - val_sparse_categorical_accuracy: 0.9208
# Epoch 40/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8195 - sparse_categorical_accuracy: 0.7499 - val_loss: 0.3159 - val_sparse_categorical_accuracy: 0.8943
# Epoch 41/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8010 - sparse_categorical_accuracy: 0.7509 - val_loss: 0.3000 - val_sparse_categorical_accuracy: 0.9170
# Epoch 42/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8016 - sparse_categorical_accuracy: 0.7455 - val_loss: 0.2566 - val_sparse_categorical_accuracy: 0.9321
# Epoch 43/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8098 - sparse_categorical_accuracy: 0.7496 - val_loss: 0.2575 - val_sparse_categorical_accuracy: 0.9245
# Epoch 44/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7685 - sparse_categorical_accuracy: 0.7605 - val_loss: 0.2499 - val_sparse_categorical_accuracy: 0.9283
# Epoch 45/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7617 - sparse_categorical_accuracy: 0.7632 - val_loss: 0.2715 - val_sparse_categorical_accuracy: 0.9321
# Epoch 46/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7601 - sparse_categorical_accuracy: 0.7669 - val_loss: 0.2700 - val_sparse_categorical_accuracy: 0.9283
# Epoch 47/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7427 - sparse_categorical_accuracy: 0.7640 - val_loss: 0.3324 - val_sparse_categorical_accuracy: 0.9019
# Epoch 48/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7428 - sparse_categorical_accuracy: 0.7705 - val_loss: 0.2841 - val_sparse_categorical_accuracy: 0.9283
# Epoch 49/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7318 - sparse_categorical_accuracy: 0.7705 - val_loss: 0.2852 - val_sparse_categorical_accuracy: 0.9170
# Epoch 50/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7325 - sparse_categorical_accuracy: 0.7724 - val_loss: 0.2904 - val_sparse_categorical_accuracy: 0.9132
# Epoch 51/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7532 - sparse_categorical_accuracy: 0.7647 - val_loss: 0.2624 - val_sparse_categorical_accuracy: 0.9321
# Epoch 52/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7306 - sparse_categorical_accuracy: 0.7754 - val_loss: 0.2868 - val_sparse_categorical_accuracy: 0.9208
# Epoch 53/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.7183 - sparse_categorical_accuracy: 0.7783 - val_loss: 0.2445 - val_sparse_categorical_accuracy: 0.9321
# Epoch 54/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6971 - sparse_categorical_accuracy: 0.7794 - val_loss: 0.2462 - val_sparse_categorical_accuracy: 0.9358
# Epoch 55/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7330 - sparse_categorical_accuracy: 0.7751 - val_loss: 0.2592 - val_sparse_categorical_accuracy: 0.9358
# Epoch 56/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7010 - sparse_categorical_accuracy: 0.7775 - val_loss: 0.2573 - val_sparse_categorical_accuracy: 0.9358
# Epoch 57/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7163 - sparse_categorical_accuracy: 0.7815 - val_loss: 0.2607 - val_sparse_categorical_accuracy: 0.9321
# Epoch 58/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6946 - sparse_categorical_accuracy: 0.7787 - val_loss: 0.2681 - val_sparse_categorical_accuracy: 0.9321
# Epoch 59/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6940 - sparse_categorical_accuracy: 0.7832 - val_loss: 0.2782 - val_sparse_categorical_accuracy: 0.9245
# Epoch 60/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7144 - sparse_categorical_accuracy: 0.7730 - val_loss: 0.2496 - val_sparse_categorical_accuracy: 0.9321
# Epoch 61/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6736 - sparse_categorical_accuracy: 0.7874 - val_loss: 0.2638 - val_sparse_categorical_accuracy: 0.9245
# Epoch 62/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6831 - sparse_categorical_accuracy: 0.7873 - val_loss: 0.2521 - val_sparse_categorical_accuracy: 0.9170
# Epoch 63/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6575 - sparse_categorical_accuracy: 0.7896 - val_loss: 0.2420 - val_sparse_categorical_accuracy: 0.9358
# Epoch 64/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6896 - sparse_categorical_accuracy: 0.7808 - val_loss: 0.2699 - val_sparse_categorical_accuracy: 0.9321
# Epoch 65/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6416 - sparse_categorical_accuracy: 0.7992 - val_loss: 0.2261 - val_sparse_categorical_accuracy: 0.9472
# Epoch 66/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6457 - sparse_categorical_accuracy: 0.7983 - val_loss: 0.2250 - val_sparse_categorical_accuracy: 0.9396
# Epoch 67/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6525 - sparse_categorical_accuracy: 0.7947 - val_loss: 0.2528 - val_sparse_categorical_accuracy: 0.9358
# Epoch 68/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6257 - sparse_categorical_accuracy: 0.8027 - val_loss: 0.2275 - val_sparse_categorical_accuracy: 0.9396
# Epoch 69/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6295 - sparse_categorical_accuracy: 0.8022 - val_loss: 0.2394 - val_sparse_categorical_accuracy: 0.9358
# Epoch 70/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6369 - sparse_categorical_accuracy: 0.7998 - val_loss: 0.2363 - val_sparse_categorical_accuracy: 0.9321
# Epoch 71/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6406 - sparse_categorical_accuracy: 0.7979 - val_loss: 0.2376 - val_sparse_categorical_accuracy: 0.9396
# Epoch 72/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6240 - sparse_categorical_accuracy: 0.8035 - val_loss: 0.2253 - val_sparse_categorical_accuracy: 0.9358
# Epoch 73/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6213 - sparse_categorical_accuracy: 0.8055 - val_loss: 0.2086 - val_sparse_categorical_accuracy: 0.9434
# Epoch 74/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6466 - sparse_categorical_accuracy: 0.7955 - val_loss: 0.2473 - val_sparse_categorical_accuracy: 0.9358
# Epoch 75/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6244 - sparse_categorical_accuracy: 0.8043 - val_loss: 0.2726 - val_sparse_categorical_accuracy: 0.9321
# Epoch 76/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5812 - sparse_categorical_accuracy: 0.8137 - val_loss: 0.2241 - val_sparse_categorical_accuracy: 0.9358
# Epoch 77/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6090 - sparse_categorical_accuracy: 0.8051 - val_loss: 0.2392 - val_sparse_categorical_accuracy: 0.9472
# Epoch 78/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6352 - sparse_categorical_accuracy: 0.7987 - val_loss: 0.2005 - val_sparse_categorical_accuracy: 0.9472
# Epoch 79/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.5972 - sparse_categorical_accuracy: 0.8162 - val_loss: 0.2703 - val_sparse_categorical_accuracy: 0.9245
# Epoch 80/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5877 - sparse_categorical_accuracy: 0.8182 - val_loss: 0.2279 - val_sparse_categorical_accuracy: 0.9358
# Epoch 81/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.6110 - sparse_categorical_accuracy: 0.8092 - val_loss: 0.1915 - val_sparse_categorical_accuracy: 0.9509
# Epoch 82/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5945 - sparse_categorical_accuracy: 0.8143 - val_loss: 0.3238 - val_sparse_categorical_accuracy: 0.9170
# Epoch 83/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.6148 - sparse_categorical_accuracy: 0.8092 - val_loss: 0.2112 - val_sparse_categorical_accuracy: 0.9396
# Epoch 84/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5785 - sparse_categorical_accuracy: 0.8169 - val_loss: 0.2135 - val_sparse_categorical_accuracy: 0.9434
# Epoch 85/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5643 - sparse_categorical_accuracy: 0.8240 - val_loss: 0.2071 - val_sparse_categorical_accuracy: 0.9434
# Epoch 86/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5670 - sparse_categorical_accuracy: 0.8237 - val_loss: 0.2017 - val_sparse_categorical_accuracy: 0.9472
# Epoch 87/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5687 - sparse_categorical_accuracy: 0.8225 - val_loss: 0.1952 - val_sparse_categorical_accuracy: 0.9547
# Epoch 88/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5836 - sparse_categorical_accuracy: 0.8143 - val_loss: 0.2394 - val_sparse_categorical_accuracy: 0.9283
# Epoch 89/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5789 - sparse_categorical_accuracy: 0.8170 - val_loss: 0.2183 - val_sparse_categorical_accuracy: 0.9472
# Epoch 90/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5760 - sparse_categorical_accuracy: 0.8186 - val_loss: 0.1905 - val_sparse_categorical_accuracy: 0.9547
# Epoch 91/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5602 - sparse_categorical_accuracy: 0.8199 - val_loss: 0.2533 - val_sparse_categorical_accuracy: 0.9283
# Epoch 92/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5527 - sparse_categorical_accuracy: 0.8235 - val_loss: 0.2067 - val_sparse_categorical_accuracy: 0.9434
# Epoch 93/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5378 - sparse_categorical_accuracy: 0.8303 - val_loss: 0.2636 - val_sparse_categorical_accuracy: 0.9396
# Epoch 94/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5658 - sparse_categorical_accuracy: 0.8214 - val_loss: 0.2034 - val_sparse_categorical_accuracy: 0.9509
# Epoch 95/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5644 - sparse_categorical_accuracy: 0.8203 - val_loss: 0.2535 - val_sparse_categorical_accuracy: 0.9283
# Epoch 96/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5494 - sparse_categorical_accuracy: 0.8259 - val_loss: 0.1903 - val_sparse_categorical_accuracy: 0.9434
# Epoch 97/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5507 - sparse_categorical_accuracy: 0.8259 - val_loss: 0.2296 - val_sparse_categorical_accuracy: 0.9434
# Epoch 98/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5675 - sparse_categorical_accuracy: 0.8212 - val_loss: 0.2892 - val_sparse_categorical_accuracy: 0.9208
# Epoch 99/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5510 - sparse_categorical_accuracy: 0.8256 - val_loss: 0.2410 - val_sparse_categorical_accuracy: 0.9358
# Epoch 100/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.5450 - sparse_categorical_accuracy: 0.8321 - val_loss: 0.2034 - val_sparse_categorical_accuracy: 0.9434

# %% [markdown]
# # Evaluación del modelo

# %%
loss = hist.history["loss"]
val_loss = hist.history["val_loss"]

plt.plot(loss, label="loss")
plt.plot(val_loss, label="val_loss")
plt.title("Loss")
plt.legend()
plt.show()

# %% [markdown]
# El acc del conjunto de validación no crece.

# %%
acc = hist.history["sparse_categorical_accuracy"]
val_acc = hist.history["val_sparse_categorical_accuracy"]

plt.plot(acc, label="acc")
plt.plot(val_acc, label="val_acc")
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
train_loss, train_acc = model.evaluate(X_train, y_train_num, verbose=0)
val_loss, val_acc = model.evaluate(X_val, y_val_num, verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test_num, verbose=0)

print("TRAIN:")
print("Loss:", round(train_loss,3))
print("Accuracy:", round(train_acc,3))

print("\nVALIDATION:")
print("Loss:", round(val_loss,3))
print("Accuracy:", round(val_acc,3))

print("\nTEST:")
print("Loss:", round(test_loss,3))
print("Accuracy:", round(test_acc,3))
# Out:
# TRAIN:
# Loss: 0.158
# Accuracy: 0.969
#
# VALIDATION:
# Loss: 0.203
# Accuracy: 0.943
#
# TEST:
# Loss: 0.322
# Accuracy: 0.906

# %% [markdown]
# # Matriz de confución
#
# Aquí podemos ver la matriz de confución del modelo y funciona como se espera.

# %%
class_names = encoder.classes_

cm = confusion_matrix(y_test_num, np.argmax(model.predict(X_test), axis=1), normalize="true")

plt.figure(figsize=(20, 20))
sns.heatmap(cm,
            annot=True, cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names,
            cbar=True)

plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.title('Matriz de Confusión')
plt.yticks(rotation=0)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step

# %% [markdown]
# # Conclusión
#
# El modelo funciona muy bien.
